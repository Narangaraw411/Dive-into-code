# %% [markdown]
# <a href="https://colab.research.google.com/github/Narangaraw411/Dive-into-code/blob/main/implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem 1 Learning and Estimation
# Please refer to the README to run the above implementation.

# %%
# !python train.py -p annotation.txt
# Out:
# Parsing annotation files
# Training images per class (19 classes) :
# {'abraham_grampa_simpson': 687,
#  'apu_nahasapeemapetilon': 206,
#  'bart_simpson': 650,
#  'bg': 0,
#  'charles_montgomery_burns': 650,
#  'chief_wiggum': 209,
#  'comic_book_guy': 208,
#  'edna_krabappel': 212,
#  'homer_simpson': 718,
#  'kent_brockman': 213,
#  'krusty_the_clown': 429,
#  'lisa_simpson': 756,
#  'marge_simpson': 629,
#  'milhouse_van_houten': 210,
#  'moe_szyslak': 403,
#  'ned_flanders': 675,
#  'nelson_muntz': 219,
#  'principal_skinner': 614,
#  'sideshow_bob': 201}
# -------------------------------
# path to config file : ./save\train_20230529-171652_config.pickle
# -------------------------------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 4, 4)         0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 4, 14, 14, 10 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 4, 7, 7, 512) 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 4, 7, 7, 512) 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 4, 7, 7, 512) 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 4, 7, 7, 2048 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 4, 7, 7, 2048 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 7, 7, 2048 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 4, 7, 7, 2048 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 4, 7, 7, 512) 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 4, 7, 7, 512) 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 4, 7, 7, 512) 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 7, 7, 2048 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 4, 7, 7, 2048 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 4, 7, 7, 512) 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 7, 7, 512) 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 4, 7, 7, 512) 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 4, 7, 7, 512) 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 7, 7, 512) 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 4, 7, 7, 2048 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 4, 7, 7, 2048 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 7, 7, 2048 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 7, 7, 2048 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 4, 1, 1, 2048 0           activation_49[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 4, 2048)      0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 1 6156        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 4 24624       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_19 (TimeDistributed (None, 4, 19)        38931       time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_19 (TimeDistribut (None, 4, 72)        147528      time_distributed_1[0][0]
# ==================================================================================================
# Total params: 28,524,055
# Trainable params: 28,417,815
# Non-trainable params: 106,240
# __________________________________________________________________________________________________
# None
# Epoch 1/10
#
#  1/10 [==>...........................] - ETA: 3:28 - rpn_cls: 12.2536 - rpn_regr: 0.2001 - detector_cls: 2.9444 - detector_regr: 0.0000e+00
#  2/10 [=====>........................] - ETA: 1:41 - rpn_cls: 12.2280 - rpn_regr: 0.2398 - detector_cls: 3.2157 - detector_regr: 0.0945
#  3/10 [========>.....................] - ETA: 1:04 - rpn_cls: 12.3310 - rpn_regr: 0.2528 - detector_cls: 3.8141 - detector_regr: 0.1718
#  4/10 [===========>..................] - ETA: 45s - rpn_cls: 11.9766 - rpn_regr: 0.2464 - detector_cls: 3.8002 - detector_regr: 0.1900
#  5/10 [==============>...............] - ETA: 32s - rpn_cls: 11.7409 - rpn_regr: 0.2388 - detector_cls: 3.9638 - detector_regr: 0.2023
#  6/10 [=================>............] - ETA: 22s - rpn_cls: 11.2863 - rpn_regr: 0.2345 - detector_cls: 4.1685 - detector_regr: 0.2213
#  7/10 [====================>.........] - ETA: 15s - rpn_cls: 10.9588 - rpn_regr: 0.2297 - detector_cls: 4.3732 - detector_regr: 0.2328
#  8/10 [=======================>......] - ETA: 9s - rpn_cls: 10.7624 - rpn_regr: 0.2249 - detector_cls: 4.5651 - detector_regr: 0.2489
#  9/10 [==========================>...] - ETA: 4s - rpn_cls: 10.4938 - rpn_regr: 0.2211 - detector_cls: 4.7410 - detector_regr: 0.2608
# 10/10 [==============================] - 42s 4s/step - rpn_cls: 10.3169 - rpn_regr: 0.2173 - detector_cls: 4.8201 - detector_regr: 0.2667
# Average number of overlapping bounding boxes from RPN = 6.1 for 10 previous iterations
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 7.818181818181818
# Classifier accuracy for bounding boxes from RPN: 0.575
# Loss RPN classifier: 8.724990628173499
# Loss RPN regression: 0.18249848634004592
# Loss Detector classifier: 5.532824897766114
# Loss Detector regression: 0.3204723849892616
# Elapsed time: 43.91879057884216[s]
# Total loss decreased from inf to 14.760786397268921, saving weights
# Epoch 2/10
#
#  1/10 [==>...........................] - ETA: 26s - rpn_cls: 6.4315 - rpn_regr: 0.0455 - detector_cls: 8.0590 - detector_regr: 7.9630
#  2/10 [=====>........................] - ETA: 24s - rpn_cls: 6.9598 - rpn_regr: 0.0801 - detector_cls: 7.0517 - detector_regr: 6.0509
#  3/10 [========>.....................] - ETA: 20s - rpn_cls: 6.9811 - rpn_regr: 0.0862 - detector_cls: 6.9397 - detector_regr: 5.2745
#  4/10 [===========>..................] - ETA: 18s - rpn_cls: 6.9448 - rpn_regr: 0.1090 - detector_cls: 6.7159 - detector_regr: 4.6952
#  5/10 [==============>...............] - ETA: 14s - rpn_cls: 6.9021 - rpn_regr: 0.1217 - detector_cls: 6.6621 - detector_regr: 4.6878
#  6/10 [=================>............] - ETA: 11s - rpn_cls: 6.6866 - rpn_regr: 0.1281 - detector_cls: 6.6711 - detector_regr: 4.5630
#  7/10 [====================>.........] - ETA: 8s - rpn_cls: 6.5205 - rpn_regr: 0.1310 - detector_cls: 6.7049 - detector_regr: 4.4017
#  8/10 [=======================>......] - ETA: 5s - rpn_cls: 6.4859 - rpn_regr: 0.1343 - detector_cls: 6.6223 - detector_regr: 4.2271
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 6.5316 - rpn_regr: 0.1387 - detector_cls: 6.5280 - detector_regr: 4.0580Average number of overlapping bounding boxes from RPN = 10.5 for 10 previous iterations
#
# 10/10 [==============================] - 26s 3s/step - rpn_cls: 6.5102 - rpn_regr: 0.1427 - detector_cls: 6.4754 - detector_regr: 3.9355
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.363636363636363
# Classifier accuracy for bounding boxes from RPN: 0.625
# Loss RPN classifier: 6.316997882091459
# Loss RPN regression: 0.17899034097790717
# Loss Detector classifier: 6.002131879329721
# Loss Detector regression: 2.832866045832634
# Elapsed time: 50.176475524902344[s]
# Epoch 3/10
#
#  1/10 [==>...........................] - ETA: 16s - rpn_cls: 12.9338 - rpn_regr: 0.1969 - detector_cls: 7.3870 - detector_regr: 5.8341
#  2/10 [=====>........................] - ETA: 15s - rpn_cls: 10.6000 - rpn_regr: 0.1810 - detector_cls: 6.4925 - detector_regr: 4.5275
#  3/10 [========>.....................] - ETA: 14s - rpn_cls: 9.5817 - rpn_regr: 0.1687 - detector_cls: 5.9675 - detector_regr: 3.8119
#  4/10 [===========>..................] - ETA: 12s - rpn_cls: 8.9631 - rpn_regr: 0.1591 - detector_cls: 5.4797 - detector_regr: 3.3283
#  5/10 [==============>...............] - ETA: 10s - rpn_cls: 8.3683 - rpn_regr: 0.1570 - detector_cls: 5.1294 - detector_regr: 2.9881
#  6/10 [=================>............] - ETA: 8s - rpn_cls: 7.8059 - rpn_regr: 0.1575 - detector_cls: 4.8569 - detector_regr: 2.7306
#  7/10 [====================>.........] - ETA: 6s - rpn_cls: 7.3267 - rpn_regr: 0.1638 - detector_cls: 4.6204 - detector_regr: 2.5231
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 6.9410 - rpn_regr: 0.1660 - detector_cls: 4.4260 - detector_regr: 2.3618Average number of overlapping bounding boxes from RPN = 8.7 for 10 previous iterations
#
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 6.5887 - rpn_regr: 0.1671 - detector_cls: 4.2587 - detector_regr: 2.2285
# 10/10 [==============================] - 22s 2s/step - rpn_cls: 6.2812 - rpn_regr: 0.1677 - detector_cls: 4.1196 - detector_regr: 2.1200
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 11.545454545454545
# Classifier accuracy for bounding boxes from RPN: 0.55
# Loss RPN classifier: 3.5137524466321337
# Loss RPN regression: 0.1733037479221821
# Loss Detector classifier: 2.8672007083892823
# Loss Detector regression: 1.1438167363405227
# Elapsed time: 24.691917181015015[s]
# Total loss decreased from 14.760786397268921 to 7.698073639284121, saving weights
# Epoch 4/10
#
#  1/10 [==>...........................] - ETA: 19s - rpn_cls: 1.3488e-05 - rpn_regr: 0.0639 - detector_cls: 2.4175 - detector_regr: 0.5649
#  2/10 [=====>........................] - ETA: 16s - rpn_cls: 1.0234e-05 - rpn_regr: 0.1029 - detector_cls: 2.2899 - detector_regr: 0.6739
#  3/10 [========>.....................] - ETA: 15s - rpn_cls: 0.0051 - rpn_regr: 0.1083 - detector_cls: 2.2539 - detector_regr: 0.7132
#  4/10 [===========>..................] - ETA: 13s - rpn_cls: 0.0068 - rpn_regr: 0.1090 - detector_cls: 2.2429 - detector_regr: 0.7500
#  5/10 [==============>...............] - ETA: 11s - rpn_cls: 0.2651 - rpn_regr: 0.1197 - detector_cls: 2.2454 - detector_regr: 0.7751
#  6/10 [=================>............] - ETA: 8s - rpn_cls: 0.5909 - rpn_regr: 0.1230 - detector_cls: 2.2388 - detector_regr: 0.7821
#  7/10 [====================>.........] - ETA: 6s - rpn_cls: 0.8402 - rpn_regr: 0.1248 - detector_cls: 2.2413 - detector_regr: 0.7755Average number of overlapping bounding boxes from RPN = 21.4 for 10 previous iterations
#
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 1.0117 - rpn_regr: 0.1257 - detector_cls: 2.2410 - detector_regr: 0.7686
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 1.1366 - rpn_regr: 0.1263 - detector_cls: 2.2440 - detector_regr: 0.7599
# 10/10 [==============================] - 22s 2s/step - rpn_cls: 1.2504 - rpn_regr: 0.1269 - detector_cls: 2.2500 - detector_regr: 0.7495
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 25.545454545454547
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.2740565317994537
# Loss RPN regression: 0.13301802650094033
# Loss Detector classifier: 2.304169738292694
# Loss Detector regression: 0.6559099316596985
# Elapsed time: 24.694467067718506[s]
# Total loss decreased from 7.698073639284121 to 5.367154228252787, saving weights
# Epoch 5/10
#
#  1/10 [==>...........................] - ETA: 21s - rpn_cls: 0.0523 - rpn_regr: 0.1799 - detector_cls: 2.3196 - detector_regr: 0.4088
#  2/10 [=====>........................] - ETA: 17s - rpn_cls: 1.9203 - rpn_regr: 0.1559 - detector_cls: 2.2478 - detector_regr: 0.5391
#  3/10 [========>.....................] - ETA: 16s - rpn_cls: 2.1221 - rpn_regr: 0.1564 - detector_cls: 2.2777 - detector_regr: 0.6151
#  4/10 [===========>..................] - ETA: 13s - rpn_cls: 2.4469 - rpn_regr: 0.1512 - detector_cls: 2.2928 - detector_regr: 0.6410
#  5/10 [==============>...............] - ETA: 11s - rpn_cls: 2.5050 - rpn_regr: 0.1455 - detector_cls: 2.2858 - detector_regr: 0.6566
#  6/10 [=================>............] - ETA: 9s - rpn_cls: 2.6355 - rpn_regr: 0.1483 - detector_cls: 2.2560 - detector_regr: 0.6471 Average number of overlapping bounding boxes from RPN = 24.2 for 10 previous iterations
#
#  7/10 [====================>.........] - ETA: 6s - rpn_cls: 2.6617 - rpn_regr: 0.1498 - detector_cls: 2.2322 - detector_regr: 0.6380
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 2.7325 - rpn_regr: 0.1508 - detector_cls: 2.2032 - detector_regr: 0.6324
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 2.7622 - rpn_regr: 0.1502 - detector_cls: 2.1798 - detector_regr: 0.6312
# 10/10 [==============================] - 22s 2s/step - rpn_cls: 2.7561 - rpn_regr: 0.1490 - detector_cls: 2.1628 - detector_regr: 0.6289
# ...
#  4/10 [===========>..................] - ETA: 14s - rpn_cls: 3.8772 - rpn_regr: 0.1623 - detector_cls: 2.7477 - detector_regr: 1.5142
#  5/10 [==============>...............] - ETA: 12s - rpn_cls: 3.4066 - rpn_regr: 0.1579 - detector_cls: 2.7041 - detector_regr: 1.3958Average number of overlapping bounding boxes from RPN = 21.9 for 10 previous iterations
#
#  6/10 [=================>............] - ETA: 9s - rpn_cls: 3.2576 - rpn_regr: 0.1540 - detector_cls: 2.6682 - detector_regr: 1.2954
#  7/10 [====================>.........] - ETA: 7s - rpn_cls: 3.0999 - rpn_regr: 0.1504 - detector_cls: 2.6359 - detector_regr: 1.2128
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 3.0450 - rpn_regr: 0.1474 - detector_cls: 2.6045 - detector_regr: 1.1451
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 3.0469 - rpn_regr: 0.1457 - detector_cls: 2.5776 - detector_regr: 1.0861
# 10/10 [==============================] - 23s 2s/step - rpn_cls: 3.0306 - rpn_regr: 0.1434 - detector_cls: 2.5515 - detector_regr: 1.0361
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.272727272727273
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.8838007082784314
# Loss RPN regression: 0.12284500263631344
# Loss Detector classifier: 2.317009460926056
# Loss Detector regression: 0.586503604054451
# Elapsed time: 25.984052896499634[s]
# Epoch 7/10
#
#  1/10 [==>...........................] - ETA: 26s - rpn_cls: 8.3084e-08 - rpn_regr: 0.1474 - detector_cls: 2.1416 - detector_regr: 1.2766
#  2/10 [=====>........................] - ETA: 22s - rpn_cls: 1.5499 - rpn_regr: 0.1394 - detector_cls: 1.7977 - detector_regr: 0.9574
#  3/10 [========>.....................] - ETA: 18s - rpn_cls: 1.8650 - rpn_regr: 0.1304 - detector_cls: 1.7567 - detector_regr: 0.8462
#  4/10 [===========>..................] - ETA: 14s - rpn_cls: 1.8666 - rpn_regr: 0.1224 - detector_cls: 1.8271 - detector_regr: 0.8285Average number of overlapping bounding boxes from RPN = 16.4 for 10 previous iterations
#
#  5/10 [==============>...............] - ETA: 12s - rpn_cls: 1.7932 - rpn_regr: 0.1153 - detector_cls: 1.8797 - detector_regr: 0.8252
#  6/10 [=================>............] - ETA: 10s - rpn_cls: 1.7026 - rpn_regr: 0.1114 - detector_cls: 1.9238 - detector_regr: 0.8226
#  7/10 [====================>.........] - ETA: 7s - rpn_cls: 1.6125 - rpn_regr: 0.1093 - detector_cls: 1.9549 - detector_regr: 0.8160
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 1.5285 - rpn_regr: 0.1086 - detector_cls: 1.9844 - detector_regr: 0.8059
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 1.4649 - rpn_regr: 0.1088 - detector_cls: 2.0091 - detector_regr: 0.7949
# 10/10 [==============================] - 23s 2s/step - rpn_cls: 1.4047 - rpn_regr: 0.1084 - detector_cls: 2.0324 - detector_regr: 0.7814
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.818181818181817
# Classifier accuracy for bounding boxes from RPN: 0.55
# Loss RPN classifier: 0.8623695943817019
# Loss RPN regression: 0.10468070805072785
# Loss Detector classifier: 2.241581791639328
# Loss Detector regression: 0.6596238613128662
# Elapsed time: 25.576223611831665[s]
# Total loss decreased from 5.367154228252787 to 3.868255955384624, saving weights
# Epoch 8/10
#
#  1/10 [==>...........................] - ETA: 21s - rpn_cls: 2.1931e-05 - rpn_regr: 0.0905 - detector_cls: 2.4634 - detector_regr: 0.3669
#  2/10 [=====>........................] - ETA: 19s - rpn_cls: 0.1441 - rpn_regr: 0.0897 - detector_cls: 2.3599 - detector_regr: 0.4480
#  3/10 [========>.....................] - ETA: 16s - rpn_cls: 0.1601 - rpn_regr: 0.0850 - detector_cls: 2.3939 - detector_regr: 0.4952Average number of overlapping bounding boxes from RPN = 20.9 for 10 previous iterations
#
#  4/10 [===========>..................] - ETA: 13s - rpn_cls: 0.1562 - rpn_regr: 0.0969 - detector_cls: 2.3878 - detector_regr: 0.5338
#  5/10 [==============>...............] - ETA: 11s - rpn_cls: 0.1481 - rpn_regr: 0.1006 - detector_cls: 2.3915 - detector_regr: 0.5529
#  6/10 [=================>............] - ETA: 8s - rpn_cls: 0.1395 - rpn_regr: 0.1074 - detector_cls: 2.3896 - detector_regr: 0.5578
#  7/10 [====================>.........] - ETA: 6s - rpn_cls: 0.1314 - rpn_regr: 0.1128 - detector_cls: 2.3843 - detector_regr: 0.5612
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 0.1240 - rpn_regr: 0.1161 - detector_cls: 2.3733 - detector_regr: 0.5656
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 0.1293 - rpn_regr: 0.1173 - detector_cls: 2.3626 - detector_regr: 0.5691
# 10/10 [==============================] - 21s 2s/step - rpn_cls: 0.1319 - rpn_regr: 0.1182 - detector_cls: 2.3519 - detector_regr: 0.5756
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 26.454545454545453
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 0.15484228795176022
# Loss RPN regression: 0.1262823473662138
# Loss Detector classifier: 2.2564970731735228
# Loss Detector regression: 0.6341112792491913
# Elapsed time: 23.56524419784546[s]
# Total loss decreased from 3.868255955384624 to 3.171732987740688, saving weights
# Epoch 9/10
#
#  1/10 [==>...........................] - ETA: 18s - rpn_cls: 9.3264 - rpn_regr: 0.0604 - detector_cls: 2.5221 - detector_regr: 0.9359
#  2/10 [=====>........................] - ETA: 15s - rpn_cls: 6.9956 - rpn_regr: 0.0805 - detector_cls: 2.4032 - detector_regr: 0.8756Average number of overlapping bounding boxes from RPN = 25.1 for 10 previous iterations
#
#  3/10 [========>.....................] - ETA: 14s - rpn_cls: 5.7018 - rpn_regr: 0.0901 - detector_cls: 2.3595 - detector_regr: 0.7956
#  4/10 [===========>..................] - ETA: 12s - rpn_cls: 4.9775 - rpn_regr: 0.0892 - detector_cls: 2.3527 - detector_regr: 0.7597
#  5/10 [==============>...............] - ETA: 10s - rpn_cls: 4.8039 - rpn_regr: 0.0924 - detector_cls: 2.3445 - detector_regr: 0.7361
#  6/10 [=================>............] - ETA: 8s - rpn_cls: 4.5746 - rpn_regr: 0.0944 - detector_cls: 2.3383 - detector_regr: 0.7115
#  7/10 [====================>.........] - ETA: 6s - rpn_cls: 4.3408 - rpn_regr: 0.0953 - detector_cls: 2.3310 - detector_regr: 0.6912
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 4.1195 - rpn_regr: 0.0960 - detector_cls: 2.3247 - detector_regr: 0.6743
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 3.9903 - rpn_regr: 0.0964 - detector_cls: 2.3168 - detector_regr: 0.6605
# 10/10 [==============================] - 21s 2s/step - rpn_cls: 3.8576 - rpn_regr: 0.0963 - detector_cls: 2.3082 - detector_regr: 0.6499
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 26.454545454545453
# Classifier accuracy for bounding boxes from RPN: 0.5
# Loss RPN classifier: 2.662924965881757
# Loss RPN regression: 0.09539200067520141
# Loss Detector classifier: 2.2312692403793335
# Loss Detector regression: 0.5543599277734756
# Elapsed time: 23.350951671600342[s]
# Epoch 10/10
#
#  1/10 [==>...........................] - ETA: 18s - rpn_cls: 6.9424 - rpn_regr: 0.0861 - detector_cls: 2.3275 - detector_regr: 0.4775Average number of overlapping bounding boxes from RPN = 27.1 for 10 previous iterations
#
#  2/10 [=====>........................] - ETA: 16s - rpn_cls: 5.2161 - rpn_regr: 0.0892 - detector_cls: 2.2753 - detector_regr: 0.4589
#  3/10 [========>.....................] - ETA: 15s - rpn_cls: 4.9219 - rpn_regr: 0.0953 - detector_cls: 2.1275 - detector_regr: 0.4037
#  4/10 [===========>..................] - ETA: 13s - rpn_cls: 4.5040 - rpn_regr: 0.1073 - detector_cls: 2.0595 - detector_regr: 0.3970
#  5/10 [==============>...............] - ETA: 10s - rpn_cls: 4.1233 - rpn_regr: 0.1112 - detector_cls: 2.0342 - detector_regr: 0.4003
#  6/10 [=================>............] - ETA: 8s - rpn_cls: 3.7982 - rpn_regr: 0.1107 - detector_cls: 2.0286 - detector_regr: 0.3988
#  7/10 [====================>.........] - ETA: 6s - rpn_cls: 3.6482 - rpn_regr: 0.1112 - detector_cls: 1.9938 - detector_regr: 0.3898
#  8/10 [=======================>......] - ETA: 4s - rpn_cls: 3.4928 - rpn_regr: 0.1115 - detector_cls: 1.9944 - detector_regr: 0.3805
#  9/10 [==========================>...] - ETA: 2s - rpn_cls: 3.4167 - rpn_regr: 0.1114 - detector_cls: 1.9813 - detector_regr: 0.3693
# 10/10 [==============================] - 22s 2s/step - rpn_cls: 3.3278 - rpn_regr: 0.1118 - detector_cls: 1.9800 - detector_regr: 0.3663
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 17.363636363636363
# Classifier accuracy for bounding boxes from RPN: 0.65
# Loss RPN classifier: 2.527541177546868
# Loss RPN regression: 0.11610757168382406
# Loss Detector classifier: 1.9675167739391326
# Loss Detector regression: 0.33879407644271853
# Elapsed time: 23.81869387626648[s]
# training is done
# -------------------------------
# path to config file : ./save\train_20230529-171652_config.pickle
# -------------------------------
# Using TensorFlow backend.
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2023-05-29 17:16:52.049348: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:63: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:488: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3626: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3454: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3603: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From c:\Users\naran\OneDrive\Documents\Python Scripts\ObjectDetection-master\model\RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3458: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:1255: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:2921: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:1238: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:671: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# !python predict.py -i ./mini_kaggle_simpson_testset -c ./save/train_20230529-171652_config.pickle
# Out:
# abraham_grampa_simpson_0.jpg
# []
# Elapsed time = 40.66428065299988[s]
# abraham_grampa_simpson_1.jpg
# []
# Elapsed time = 26.784372091293335[s]
# abraham_grampa_simpson_10.jpg
# []
# Elapsed time = 25.424753665924072[s]
# abraham_grampa_simpson_11.jpg
# []
# Elapsed time = 24.999314785003662[s]
# abraham_grampa_simpson_12.jpg
# []
# Elapsed time = 25.522693157196045[s]
# abraham_grampa_simpson_13.jpg
# []
# Elapsed time = 27.991605520248413[s]
# abraham_grampa_simpson_14.jpg
# []
# Elapsed time = 24.594385862350464[s]
# abraham_grampa_simpson_15.jpg
# []
# Elapsed time = 209.8050765991211[s]
# abraham_grampa_simpson_16.jpg
# []
# Elapsed time = 24.938263654708862[s]
# abraham_grampa_simpson_17.jpg
# []
# Elapsed time = 25.697082042694092[s]
# abraham_grampa_simpson_18.jpg
# []
# Elapsed time = 29.708694219589233[s]
# abraham_grampa_simpson_19.jpg
# []
# Elapsed time = 29.631468296051025[s]
# abraham_grampa_simpson_2.jpg
# []
# Elapsed time = 31.965482473373413[s]
# abraham_grampa_simpson_20.jpg
# []
# Elapsed time = 27.758180856704712[s]
# abraham_grampa_simpson_21.jpg
# []
# Elapsed time = 24.332664251327515[s]
# abraham_grampa_simpson_22.jpg
# []
# Elapsed time = 26.75294327735901[s]
# abraham_grampa_simpson_23.jpg
# []
# Elapsed time = 28.932647466659546[s]
# abraham_grampa_simpson_24.jpg
# []
# Elapsed time = 26.285842418670654[s]
# abraham_grampa_simpson_25.jpg
# []
# Elapsed time = 29.39704918861389[s]
# abraham_grampa_simpson_26.jpg
# []
# Elapsed time = 27.34330916404724[s]
# abraham_grampa_simpson_27.jpg
# []
# Elapsed time = 26.221156120300293[s]
# abraham_grampa_simpson_28.jpg
# []
# Elapsed time = 28.343786239624023[s]
# abraham_grampa_simpson_29.jpg
# []
# Elapsed time = 25.852533102035522[s]
# abraham_grampa_simpson_3.jpg
# []
# Elapsed time = 25.344838619232178[s]
# abraham_grampa_simpson_30.jpg
# []
# Elapsed time = 23.1980938911438[s]
# abraham_grampa_simpson_31.jpg
# []
# Elapsed time = 25.61049222946167[s]
# abraham_grampa_simpson_32.jpg
# []
# Elapsed time = 22.72441554069519[s]
# abraham_grampa_simpson_33.jpg
# []
# Elapsed time = 22.25623917579651[s]
# abraham_grampa_simpson_34.jpg
# []
# Elapsed time = 24.0189528465271[s]
# abraham_grampa_simpson_35.jpg
# []
# Elapsed time = 23.038494110107422[s]
# abraham_grampa_simpson_36.jpg
# []
# Elapsed time = 23.49438786506653[s]
# abraham_grampa_simpson_37.jpg
# []
# Elapsed time = 23.225314378738403[s]
# abraham_grampa_simpson_38.jpg
# []
# Elapsed time = 21.41175150871277[s]
# abraham_grampa_simpson_39.jpg
# []
# Elapsed time = 22.847524404525757[s]
# abraham_grampa_simpson_4.jpg
# []
# Elapsed time = 21.20291566848755[s]
# abraham_grampa_simpson_40.jpg
# []
# Elapsed time = 24.301856517791748[s]
# abraham_grampa_simpson_41.jpg
# []
# Elapsed time = 23.307084321975708[s]
# abraham_grampa_simpson_42.jpg
# []
# Elapsed time = 21.055546522140503[s]
# abraham_grampa_simpson_43.jpg
# []
# Elapsed time = 26.003002643585205[s]
# abraham_grampa_simpson_44.jpg
# []
# Elapsed time = 27.07759976387024[s]
# abraham_grampa_simpson_45.jpg
# []
# Elapsed time = 13.302748918533325[s]
# abraham_grampa_simpson_46.jpg
# []
# Elapsed time = 5.501832723617554[s]
# abraham_grampa_simpson_47.jpg
# []
# Elapsed time = 5.320015907287598[s]
# abraham_grampa_simpson_48.jpg
# []
# Elapsed time = 5.196455717086792[s]
# abraham_grampa_simpson_49.jpg
# []
# Elapsed time = 5.366606712341309[s]
# abraham_grampa_simpson_7.jpg
# []
# Elapsed time = 5.5017409324646[s]
# abraham_grampa_simpson_8.jpg
# []
# Elapsed time = 6.25114631652832[s]
# abraham_grampa_simpson_9.jpg
# []
# Elapsed time = 6.170719861984253[s]
# apu_nahasapeemapetilon_0.jpg
# []
# Elapsed time = 5.531399726867676[s]
# apu_nahasapeemapetilon_1.jpg
# []
# Elapsed time = 6.0057759284973145[s]
# apu_nahasapeemapetilon_10.jpg
# []
# Elapsed time = 5.254138946533203[s]
# apu_nahasapeemapetilon_11.jpg
# []
# Elapsed time = 5.245960235595703[s]
# apu_nahasapeemapetilon_12.jpg
# []
# Elapsed time = 5.351171255111694[s]
# apu_nahasapeemapetilon_13.jpg
# []
# Elapsed time = 5.511134624481201[s]
# apu_nahasapeemapetilon_14.jpg
# []
# Elapsed time = 6.5388524532318115[s]
# apu_nahasapeemapetilon_15.jpg
# []
# Elapsed time = 6.466223239898682[s]
# apu_nahasapeemapetilon_16.jpg
# []
# Elapsed time = 5.8612961769104[s]
# apu_nahasapeemapetilon_17.jpg
# []
# Elapsed time = 5.768922567367554[s]
# apu_nahasapeemapetilon_18.jpg
# []
# Elapsed time = 5.708401918411255[s]
# apu_nahasapeemapetilon_19.jpg
# []
# Elapsed time = 5.5354626178741455[s]
# apu_nahasapeemapetilon_2.jpg
# []
# Elapsed time = 5.494798421859741[s]
# apu_nahasapeemapetilon_20.jpg
# []
# Elapsed time = 5.56485652923584[s]
# apu_nahasapeemapetilon_21.jpg
# []
# Elapsed time = 5.496021032333374[s]
# apu_nahasapeemapetilon_22.jpg
# []
# Elapsed time = 5.383410692214966[s]
# apu_nahasapeemapetilon_23.jpg
# []
# Elapsed time = 5.138018369674683[s]
# apu_nahasapeemapetilon_24.jpg
# []
# Elapsed time = 5.188543796539307[s]
# apu_nahasapeemapetilon_25.jpg
# []
# Elapsed time = 5.115683317184448[s]
# apu_nahasapeemapetilon_26.jpg
# []
# Elapsed time = 5.348680257797241[s]
# apu_nahasapeemapetilon_27.jpg
# []
# Elapsed time = 5.216262578964233[s]
# apu_nahasapeemapetilon_28.jpg
# []
# Elapsed time = 5.3324151039123535[s]
# apu_nahasapeemapetilon_29.jpg
# []
# Elapsed time = 5.175029277801514[s]
# apu_nahasapeemapetilon_3.jpg
# []
# Elapsed time = 5.256794214248657[s]
# apu_nahasapeemapetilon_30.jpg
# []
# Elapsed time = 5.518423795700073[s]
# apu_nahasapeemapetilon_31.jpg
# []
# Elapsed time = 5.10330605506897[s]
# apu_nahasapeemapetilon_32.jpg
# []
# Elapsed time = 5.262548446655273[s]
# apu_nahasapeemapetilon_33.jpg
# []
# Elapsed time = 5.966062307357788[s]
# apu_nahasapeemapetilon_34.jpg
# []
# Elapsed time = 6.766082763671875[s]
# apu_nahasapeemapetilon_35.jpg
# []
# Elapsed time = 6.664713621139526[s]
# apu_nahasapeemapetilon_36.jpg
# []
# Elapsed time = 6.836877107620239[s]
# apu_nahasapeemapetilon_37.jpg
# []
# Elapsed time = 6.8421454429626465[s]
# apu_nahasapeemapetilon_38.jpg
# []
# Elapsed time = 6.944388151168823[s]
# apu_nahasapeemapetilon_39.jpg
# []
# Elapsed time = 7.1412389278411865[s]
# apu_nahasapeemapetilon_4.jpg
# []
# Elapsed time = 6.860514402389526[s]
# apu_nahasapeemapetilon_40.jpg
# []
# Elapsed time = 5.936111688613892[s]
# apu_nahasapeemapetilon_41.jpg
# []
# Elapsed time = 6.269132614135742[s]
# apu_nahasapeemapetilon_42.jpg
# []
# Elapsed time = 6.668024778366089[s]
# apu_nahasapeemapetilon_43.jpg
# []
# Elapsed time = 6.297472715377808[s]
# apu_nahasapeemapetilon_44.jpg
# []
# Elapsed time = 6.919864177703857[s]
# apu_nahasapeemapetilon_45.jpg
# []
# Elapsed time = 6.859487295150757[s]
# apu_nahasapeemapetilon_46.jpg
# []
# Elapsed time = 6.440235614776611[s]
# apu_nahasapeemapetilon_47.jpg
# []
# Elapsed time = 7.046533823013306[s]
# apu_nahasapeemapetilon_48.jpg
# []
# Elapsed time = 7.197473049163818[s]
# apu_nahasapeemapetilon_49.jpg
# []
# Elapsed time = 6.517069101333618[s]
# apu_nahasapeemapetilon_5.jpg
# []
# Elapsed time = 6.734579801559448[s]
# apu_nahasapeemapetilon_6.jpg
# []
# Elapsed time = 5.91060209274292[s]
# apu_nahasapeemapetilon_7.jpg
# []
# Elapsed time = 6.724251985549927[s]
# apu_nahasapeemapetilon_8.jpg
# []
# Elapsed time = 6.1823766231536865[s]
# apu_nahasapeemapetilon_9.jpg
# []
# Elapsed time = 6.691691160202026[s]
# bart_simpson_0.jpg
# []
# Elapsed time = 6.035411357879639[s]
# bart_simpson_1.jpg
# []
# Elapsed time = 6.865455627441406[s]
# bart_simpson_10.jpg
# []
# Elapsed time = 7.132625341415405[s]
# bart_simpson_11.jpg
# []
# Elapsed time = 5.465914964675903[s]
# bart_simpson_12.jpg
# []
# Elapsed time = 6.389060735702515[s]
# bart_simpson_13.jpg
# []
# Elapsed time = 6.726644515991211[s]
# bart_simpson_14.jpg
# []
# Elapsed time = 6.502971172332764[s]
# bart_simpson_15.jpg
# []
# Elapsed time = 6.153502941131592[s]
# bart_simpson_16.jpg
# []
# Elapsed time = 6.727729320526123[s]
# bart_simpson_17.jpg
# []
# Elapsed time = 6.3664469718933105[s]
# bart_simpson_18.jpg
# []
# Elapsed time = 6.571906566619873[s]
# bart_simpson_19.jpg
# []
# Elapsed time = 6.632812023162842[s]
# bart_simpson_2.jpg
# []
# Elapsed time = 7.353034734725952[s]
# bart_simpson_20.jpg
# []
# Elapsed time = 7.46598744392395[s]
# bart_simpson_21.jpg
# []
# Elapsed time = 6.488387823104858[s]
# bart_simpson_22.jpg
# []
# Elapsed time = 6.638656854629517[s]
# bart_simpson_23.jpg
# []
# Elapsed time = 6.687514305114746[s]
# bart_simpson_24.jpg
# []
# Elapsed time = 6.59682822227478[s]
# bart_simpson_25.jpg
# []
# Elapsed time = 5.9053568840026855[s]
# bart_simpson_26.jpg
# []
# Elapsed time = 6.582735776901245[s]
# bart_simpson_27.jpg
# []
# Elapsed time = 6.6252121925354[s]
# bart_simpson_28.jpg
# []
# Elapsed time = 6.596209287643433[s]
# bart_simpson_29.jpg
# []
# Elapsed time = 7.686374664306641[s]
# bart_simpson_3.jpg
# []
# Elapsed time = 7.230749607086182[s]
# bart_simpson_30.jpg
# []
# Elapsed time = 7.098447322845459[s]
# bart_simpson_31.jpg
# []
# Elapsed time = 6.645186185836792[s]
# bart_simpson_32.jpg
# []
# Elapsed time = 6.289783716201782[s]
# bart_simpson_33.jpg
# []
# Elapsed time = 6.12938928604126[s]
# bart_simpson_34.jpg
# []
# Elapsed time = 5.308964490890503[s]
# bart_simpson_35.jpg
# []
# Elapsed time = 6.482482671737671[s]
# bart_simpson_36.jpg
# []
# Elapsed time = 6.7994256019592285[s]
# bart_simpson_37.jpg
# []
# Elapsed time = 6.36755895614624[s]
# bart_simpson_38.jpg
# []
# Elapsed time = 6.410952806472778[s]
# bart_simpson_39.jpg
# []
# Elapsed time = 6.7482616901397705[s]
# bart_simpson_4.jpg
# []
# Elapsed time = 7.062588691711426[s]
# bart_simpson_40.jpg
# []
# Elapsed time = 7.627400875091553[s]
# bart_simpson_41.jpg
# []
# Elapsed time = 7.015239715576172[s]
# bart_simpson_42.jpg
# []
# Elapsed time = 6.862869739532471[s]
# bart_simpson_43.jpg
# []
# Elapsed time = 6.823901891708374[s]
# bart_simpson_44.jpg
# []
# Elapsed time = 6.683912038803101[s]
# bart_simpson_45.jpg
# []
# Elapsed time = 6.829599380493164[s]
# bart_simpson_46.jpg
# []
# Elapsed time = 7.371870279312134[s]
# bart_simpson_47.jpg
# []
# Elapsed time = 7.156597375869751[s]
# bart_simpson_48.jpg
# []
# Elapsed time = 6.510493516921997[s]
# bart_simpson_49.jpg
# []
# Elapsed time = 6.998388290405273[s]
# bart_simpson_5.jpg
# []
# Elapsed time = 6.835110425949097[s]
# bart_simpson_6.jpg
# []
# Elapsed time = 7.11610746383667[s]
# bart_simpson_7.jpg
# []
# Elapsed time = 6.179136753082275[s]
# bart_simpson_8.jpg
# []
# Elapsed time = 6.916785478591919[s]
# bart_simpson_9.jpg
# []
# Elapsed time = 6.91070556640625[s]
# charles_montgomery_burns_0.jpg
# []
# Elapsed time = 5.853017568588257[s]
# charles_montgomery_burns_1.jpg
# []
# Elapsed time = 6.8860437870025635[s]
# charles_montgomery_burns_10.jpg
# []
# Elapsed time = 6.804815292358398[s]
# charles_montgomery_burns_11.jpg
# []
# Elapsed time = 6.481782674789429[s]
# charles_montgomery_burns_12.jpg
# []
# Elapsed time = 5.852184295654297[s]
# charles_montgomery_burns_13.jpg
# []
# Elapsed time = 6.283001661300659[s]
# charles_montgomery_burns_14.jpg
# []
# Elapsed time = 6.983536243438721[s]
# charles_montgomery_burns_15.jpg
# []
# Elapsed time = 6.466226577758789[s]
# charles_montgomery_burns_16.jpg
# []
# Elapsed time = 7.784336805343628[s]
# charles_montgomery_burns_17.jpg
# []
# Elapsed time = 6.801067113876343[s]
# charles_montgomery_burns_18.jpg
# []
# Elapsed time = 6.863339424133301[s]
# charles_montgomery_burns_19.jpg
# []
# Elapsed time = 6.851018667221069[s]
# charles_montgomery_burns_2.jpg
# []
# Elapsed time = 6.725396156311035[s]
# charles_montgomery_burns_20.jpg
# []
# Elapsed time = 6.171419143676758[s]
# charles_montgomery_burns_21.jpg
# []
# Elapsed time = 6.380542516708374[s]
# charles_montgomery_burns_22.jpg
# []
# Elapsed time = 6.7001097202301025[s]
# charles_montgomery_burns_24.jpg
# []
# Elapsed time = 6.559100866317749[s]
# charles_montgomery_burns_25.jpg
# []
# Elapsed time = 7.061208009719849[s]
# charles_montgomery_burns_26.jpg
# []
# Elapsed time = 7.0244081020355225[s]
# charles_montgomery_burns_27.jpg
# []
# Elapsed time = 6.824500799179077[s]
# charles_montgomery_burns_28.jpg
# []
# Elapsed time = 7.230114459991455[s]
# charles_montgomery_burns_29.jpg
# []
# Elapsed time = 7.435955047607422[s]
# charles_montgomery_burns_3.jpg
# []
# Elapsed time = 6.736284255981445[s]
# charles_montgomery_burns_30.jpg
# []
# Elapsed time = 6.581505298614502[s]
# charles_montgomery_burns_31.jpg
# []
# Elapsed time = 6.680541038513184[s]
# charles_montgomery_burns_32.jpg
# []
# Elapsed time = 6.6186583042144775[s]
# charles_montgomery_burns_33.jpg
# []
# Elapsed time = 6.718252420425415[s]
# charles_montgomery_burns_34.jpg
# []
# Elapsed time = 6.800769567489624[s]
# charles_montgomery_burns_35.jpg
# []
# Elapsed time = 6.581393480300903[s]
# charles_montgomery_burns_36.jpg
# []
# Elapsed time = 5.673754453659058[s]
# charles_montgomery_burns_37.jpg
# []
# Elapsed time = 6.601383686065674[s]
# charles_montgomery_burns_38.jpg
# []
# Elapsed time = 6.715947389602661[s]
# charles_montgomery_burns_39.jpg
# []
# Elapsed time = 7.113226652145386[s]
# charles_montgomery_burns_4.jpg
# []
# Elapsed time = 9.274845361709595[s]
# charles_montgomery_burns_40.jpg
# []
# Elapsed time = 9.769940614700317[s]
# charles_montgomery_burns_41.jpg
# []
# Elapsed time = 8.845918893814087[s]
# charles_montgomery_burns_43.jpg
# []
# Elapsed time = 8.171781539916992[s]
# charles_montgomery_burns_44.jpg
# []
# Elapsed time = 8.093368530273438[s]
# charles_montgomery_burns_45.jpg
# []
# Elapsed time = 7.772921562194824[s]
# charles_montgomery_burns_46.jpg
# []
# Elapsed time = 7.8872740268707275[s]
# charles_montgomery_burns_47.jpg
# []
# Elapsed time = 9.672876834869385[s]
# charles_montgomery_burns_48.jpg
# []
# Elapsed time = 7.866151332855225[s]
# charles_montgomery_burns_49.jpg
# []
# Elapsed time = 6.781450986862183[s]
# charles_montgomery_burns_5.jpg
# []
# Elapsed time = 6.005575656890869[s]
# charles_montgomery_burns_6.jpg
# []
# Elapsed time = 6.885618686676025[s]
# charles_montgomery_burns_7.jpg
# []
# Elapsed time = 6.763891696929932[s]
# charles_montgomery_burns_8.jpg
# []
# Elapsed time = 6.821403980255127[s]
# charles_montgomery_burns_9.jpg
# []
# Elapsed time = 6.608027458190918[s]
# chief_wiggum_0.jpg
# []
# Elapsed time = 6.565258979797363[s]
# chief_wiggum_1.jpg
# []
# Elapsed time = 6.378854751586914[s]
# chief_wiggum_10.jpg
# []
# Elapsed time = 6.979341983795166[s]
# chief_wiggum_11.jpg
# []
# Elapsed time = 6.643012285232544[s]
# chief_wiggum_12.jpg
# []
# Elapsed time = 6.696032285690308[s]
# chief_wiggum_13.jpg
# []
# Elapsed time = 6.2464563846588135[s]
# chief_wiggum_14.jpg
# []
# Elapsed time = 6.747515439987183[s]
# chief_wiggum_15.jpg
# []
# Elapsed time = 7.084202527999878[s]
# chief_wiggum_16.jpg
# []
# Elapsed time = 7.09708046913147[s]
# chief_wiggum_17.jpg
# []
# Elapsed time = 6.826820373535156[s]
# chief_wiggum_18.jpg
# []
# Elapsed time = 7.413609504699707[s]
# chief_wiggum_19.jpg
# []
# Elapsed time = 7.440738677978516[s]
# chief_wiggum_2.jpg
# []
# Elapsed time = 6.536447763442993[s]
# chief_wiggum_20.jpg
# []
# Elapsed time = 6.49964451789856[s]
# chief_wiggum_21.jpg
# []
# Elapsed time = 6.457356214523315[s]
# chief_wiggum_22.jpg
# []
# Elapsed time = 6.5067338943481445[s]
# chief_wiggum_23.jpg
# []
# Elapsed time = 6.612090349197388[s]
# chief_wiggum_24.jpg
# []
# Elapsed time = 6.09402060508728[s]
# chief_wiggum_25.jpg
# []
# Elapsed time = 6.383337736129761[s]
# chief_wiggum_26.jpg
# []
# Elapsed time = 7.7959983348846436[s]
# chief_wiggum_27.jpg
# []
# Elapsed time = 7.027832269668579[s]
# chief_wiggum_28.jpg
# []
# Elapsed time = 6.8426783084869385[s]
# chief_wiggum_29.jpg
# []
# Elapsed time = 6.596779108047485[s]
# chief_wiggum_3.jpg
# []
# Elapsed time = 7.234496831893921[s]
# chief_wiggum_30.jpg
# []
# Elapsed time = 6.333607196807861[s]
# chief_wiggum_31.jpg
# []
# Elapsed time = 6.780184268951416[s]
# chief_wiggum_32.jpg
# []
# Elapsed time = 6.125799894332886[s]
# chief_wiggum_33.jpg
# []
# Elapsed time = 6.8229100704193115[s]
# chief_wiggum_34.jpg
# []
# Elapsed time = 7.992222785949707[s]
# chief_wiggum_35.jpg
# []
# Elapsed time = 6.823703050613403[s]
# chief_wiggum_36.jpg
# []
# Elapsed time = 6.72010064125061[s]
# chief_wiggum_37.jpg
# []
# Elapsed time = 6.399219989776611[s]
# chief_wiggum_38.jpg
# []
# Elapsed time = 6.737657785415649[s]
# chief_wiggum_39.jpg
# []
# Elapsed time = 6.487882375717163[s]
# chief_wiggum_4.jpg
# []
# Elapsed time = 6.762899160385132[s]
# chief_wiggum_40.jpg
# []
# Elapsed time = 6.121067523956299[s]
# chief_wiggum_41.jpg
# []
# Elapsed time = 6.695553541183472[s]
# chief_wiggum_42.jpg
# []
# Elapsed time = 6.697340965270996[s]
# chief_wiggum_43.jpg
# []
# Elapsed time = 7.019490480422974[s]
# chief_wiggum_44.jpg
# []
# Elapsed time = 6.547202825546265[s]
# chief_wiggum_45.jpg
# []
# Elapsed time = 7.516723394393921[s]
# chief_wiggum_46.jpg
# []
# Elapsed time = 7.921863079071045[s]
# chief_wiggum_47.jpg
# []
# Elapsed time = 6.893801212310791[s]
# chief_wiggum_48.jpg
# []
# Elapsed time = 6.25811505317688[s]
# chief_wiggum_49.jpg
# []
# Elapsed time = 6.930408477783203[s]
# chief_wiggum_5.jpg
# []
# Elapsed time = 6.605369329452515[s]
# chief_wiggum_6.jpg
# []
# Elapsed time = 6.407610654830933[s]
# chief_wiggum_7.jpg
# []
# Elapsed time = 5.87057900428772[s]
# chief_wiggum_8.jpg
# []
# Elapsed time = 6.244877576828003[s]
# chief_wiggum_9.jpg
# []
# Elapsed time = 6.7621169090271[s]
# comic_book_guy_0.jpg
# []
# Elapsed time = 6.62582802772522[s]
# comic_book_guy_1.jpg
# []
# Elapsed time = 7.332154273986816[s]
# comic_book_guy_10.jpg
# []
# Elapsed time = 6.639165163040161[s]
# comic_book_guy_11.jpg
# []
# Elapsed time = 7.079692125320435[s]
# comic_book_guy_12.jpg
# []
# Elapsed time = 6.5364298820495605[s]
# comic_book_guy_13.jpg
# []
# Elapsed time = 6.723313570022583[s]
# comic_book_guy_14.jpg
# []
# Elapsed time = 7.185622215270996[s]
# comic_book_guy_15.jpg
# []
# Elapsed time = 6.793758153915405[s]
# comic_book_guy_16.jpg
# []
# Elapsed time = 6.503248929977417[s]
# comic_book_guy_17.jpg
# []
# Elapsed time = 6.4978344440460205[s]
# comic_book_guy_18.jpg
# []
# Elapsed time = 6.513125419616699[s]
# comic_book_guy_19.jpg
# []
# Elapsed time = 6.7753190994262695[s]
# comic_book_guy_2.jpg
# []
# Elapsed time = 7.139224052429199[s]
# comic_book_guy_20.jpg
# []
# Elapsed time = 8.249948501586914[s]
# comic_book_guy_21.jpg
# []
# Elapsed time = 7.09809684753418[s]
# comic_book_guy_22.jpg
# []
# Elapsed time = 6.859595537185669[s]
# comic_book_guy_23.jpg
# []
# Elapsed time = 6.642430543899536[s]
# comic_book_guy_24.jpg
# []
# Elapsed time = 6.917945384979248[s]
# comic_book_guy_25.jpg
# []
# Elapsed time = 6.966807842254639[s]
# comic_book_guy_26.jpg
# []
# Elapsed time = 6.363378286361694[s]
# comic_book_guy_27.jpg
# []
# Elapsed time = 6.592835903167725[s]
# comic_book_guy_28.jpg
# []
# Elapsed time = 6.733375787734985[s]
# comic_book_guy_29.jpg
# []
# Elapsed time = 6.758080959320068[s]
# comic_book_guy_3.jpg
# []
# Elapsed time = 7.459540367126465[s]
# comic_book_guy_30.jpg
# []
# Elapsed time = 7.137666463851929[s]
# comic_book_guy_31.jpg
# []
# Elapsed time = 7.130904674530029[s]
# comic_book_guy_32.jpg
# []
# Elapsed time = 7.177831172943115[s]
# comic_book_guy_33.jpg
# []
# Elapsed time = 6.590700387954712[s]
# comic_book_guy_34.jpg
# []
# Elapsed time = 6.554803848266602[s]
# comic_book_guy_36.jpg
# []
# Elapsed time = 7.042339324951172[s]
# comic_book_guy_37.jpg
# []
# Elapsed time = 6.445028305053711[s]
# comic_book_guy_38.jpg
# []
# Elapsed time = 7.76432991027832[s]
# comic_book_guy_39.jpg
# []
# Elapsed time = 6.928560495376587[s]
# comic_book_guy_4.jpg
# []
# Elapsed time = 6.6956164836883545[s]
# comic_book_guy_40.jpg
# []
# Elapsed time = 6.725043296813965[s]
# comic_book_guy_41.jpg
# []
# Elapsed time = 7.437059640884399[s]
# comic_book_guy_42.jpg
# []
# Elapsed time = 8.020721197128296[s]
# comic_book_guy_43.jpg
# []
# Elapsed time = 7.525176286697388[s]
# comic_book_guy_44.jpg
# []
# Elapsed time = 7.334967851638794[s]
# comic_book_guy_45.jpg
# []
# Elapsed time = 7.586761713027954[s]
# comic_book_guy_46.jpg
# []
# Elapsed time = 8.291319847106934[s]
# comic_book_guy_47.jpg
# []
# Elapsed time = 6.910271644592285[s]
# comic_book_guy_48.jpg
# []
# Elapsed time = 6.990350246429443[s]
# comic_book_guy_49.jpg
# []
# Elapsed time = 6.65472936630249[s]
# comic_book_guy_5.jpg
# []
# Elapsed time = 6.936019420623779[s]
# comic_book_guy_6.jpg
# []
# Elapsed time = 6.692898511886597[s]
# comic_book_guy_7.jpg
# []
# Elapsed time = 6.85530161857605[s]
# comic_book_guy_8.jpg
# []
# Elapsed time = 8.36538577079773[s]
# comic_book_guy_9.jpg
# []
# Elapsed time = 6.661993741989136[s]
# edna_krabappel_0.jpg
# []
# Elapsed time = 6.463585376739502[s]
# edna_krabappel_1.jpg
# []
# Elapsed time = 6.8712546825408936[s]
# edna_krabappel_10.jpg
# []
# Elapsed time = 6.241171360015869[s]
# edna_krabappel_11.jpg
# []
# Elapsed time = 6.722285032272339[s]
# edna_krabappel_12.jpg
# []
# Elapsed time = 6.652599811553955[s]
# edna_krabappel_13.jpg
# []
# Elapsed time = 6.939739465713501[s]
# edna_krabappel_14.jpg
# []
# Elapsed time = 6.733639717102051[s]
# edna_krabappel_15.jpg
# []
# Elapsed time = 6.747140645980835[s]
# edna_krabappel_16.jpg
# []
# Elapsed time = 6.625114679336548[s]
# edna_krabappel_17.jpg
# []
# Elapsed time = 6.607651233673096[s]
# edna_krabappel_18.jpg
# []
# Elapsed time = 7.467633485794067[s]
# edna_krabappel_19.jpg
# []
# Elapsed time = 6.86212682723999[s]
# edna_krabappel_2.jpg
# []
# Elapsed time = 6.90868353843689[s]
# edna_krabappel_20.jpg
# []
# Elapsed time = 6.772514581680298[s]
# edna_krabappel_21.jpg
# []
# Elapsed time = 6.615179777145386[s]
# edna_krabappel_22.jpg
# []
# Elapsed time = 7.113410711288452[s]
# edna_krabappel_23.jpg
# []
# Elapsed time = 7.478295803070068[s]
# edna_krabappel_24.jpg
# []
# Elapsed time = 7.436702728271484[s]
# edna_krabappel_25.jpg
# []
# Elapsed time = 6.808336019515991[s]
# edna_krabappel_26.jpg
# []
# Elapsed time = 7.036158084869385[s]
# edna_krabappel_27.jpg
# []
# Elapsed time = 6.574634313583374[s]
# edna_krabappel_28.jpg
# []
# Elapsed time = 6.7981719970703125[s]
# edna_krabappel_29.jpg
# []
# Elapsed time = 7.752182483673096[s]
# edna_krabappel_3.jpg
# []
# Elapsed time = 8.116943359375[s]
# edna_krabappel_30.jpg
# []
# Elapsed time = 6.99037766456604[s]
# edna_krabappel_31.jpg
# []
# Elapsed time = 7.124014139175415[s]
# edna_krabappel_32.jpg
# []
# Elapsed time = 9.49205207824707[s]
# edna_krabappel_33.jpg
# []
# Elapsed time = 8.365343570709229[s]
# edna_krabappel_34.jpg
# []
# Elapsed time = 7.776772975921631[s]
# edna_krabappel_35.jpg
# []
# Elapsed time = 8.132955551147461[s]
# edna_krabappel_36.jpg
# []
# Elapsed time = 7.718869209289551[s]
# edna_krabappel_37.jpg
# []
# Elapsed time = 8.263995170593262[s]
# edna_krabappel_38.jpg
# []
# Elapsed time = 8.157820463180542[s]
# edna_krabappel_39.jpg
# []
# Elapsed time = 6.780226945877075[s]
# edna_krabappel_4.jpg
# []
# Elapsed time = 6.4966511726379395[s]
# edna_krabappel_40.jpg
# []
# Elapsed time = 6.179860591888428[s]
# edna_krabappel_41.jpg
# []
# Elapsed time = 5.84809684753418[s]
# edna_krabappel_42.jpg
# []
# Elapsed time = 6.717495679855347[s]
# edna_krabappel_43.jpg
# []
# Elapsed time = 6.98551344871521[s]
# edna_krabappel_44.jpg
# []
# Elapsed time = 7.7760169506073[s]
# edna_krabappel_45.jpg
# []
# Elapsed time = 7.289541721343994[s]
# edna_krabappel_46.jpg
# []
# Elapsed time = 7.1241490840911865[s]
# edna_krabappel_47.jpg
# []
# Elapsed time = 7.256947040557861[s]
# edna_krabappel_48.jpg
# []
# Elapsed time = 6.243306636810303[s]
# edna_krabappel_49.jpg
# []
# Elapsed time = 6.351836919784546[s]
# edna_krabappel_5.jpg
# []
# Elapsed time = 6.519975423812866[s]
# edna_krabappel_6.jpg
# []
# Elapsed time = 8.728878259658813[s]
# edna_krabappel_7.jpg
# []
# Elapsed time = 6.926409959793091[s]
# edna_krabappel_8.jpg
# []
# Elapsed time = 7.081095218658447[s]
# edna_krabappel_9.jpg
# []
# Elapsed time = 6.817608118057251[s]
# homer_simpson_0.jpg
# []
# Elapsed time = 6.723683834075928[s]
# homer_simpson_1.jpg
# []
# Elapsed time = 6.7240471839904785[s]
# homer_simpson_10.jpg
# []
# Elapsed time = 6.780622482299805[s]
# homer_simpson_11.jpg
# []
# Elapsed time = 6.823211193084717[s]
# homer_simpson_12.jpg
# []
# Elapsed time = 7.0936198234558105[s]
# homer_simpson_13.jpg
# []
# Elapsed time = 6.8239264488220215[s]
# homer_simpson_14.jpg
# []
# Elapsed time = 6.853222608566284[s]
# homer_simpson_15.jpg
# []
# Elapsed time = 6.7178895473480225[s]
# homer_simpson_16.jpg
# []
# Elapsed time = 6.595498323440552[s]
# homer_simpson_17.jpg
# []
# Elapsed time = 6.793286085128784[s]
# homer_simpson_18.jpg
# []
# Elapsed time = 7.358856678009033[s]
# homer_simpson_19.jpg
# []
# Elapsed time = 6.2500200271606445[s]
# homer_simpson_2.jpg
# []
# Elapsed time = 7.010591745376587[s]
# homer_simpson_20.jpg
# []
# Elapsed time = 6.351145029067993[s]
# homer_simpson_21.jpg
# []
# Elapsed time = 6.639653444290161[s]
# homer_simpson_22.jpg
# []
# Elapsed time = 7.462745189666748[s]
# homer_simpson_23.jpg
# []
# Elapsed time = 7.636661529541016[s]
# homer_simpson_24.jpg
# []
# Elapsed time = 7.71332311630249[s]
# homer_simpson_25.jpg
# []
# Elapsed time = 6.855377912521362[s]
# homer_simpson_26.jpg
# []
# Elapsed time = 6.751112461090088[s]
# homer_simpson_27.jpg
# []
# Elapsed time = 6.308432340621948[s]
# homer_simpson_28.jpg
# []
# Elapsed time = 6.767274379730225[s]
# homer_simpson_29.jpg
# []
# Elapsed time = 6.143660545349121[s]
# homer_simpson_3.jpg
# []
# Elapsed time = 6.829935073852539[s]
# homer_simpson_30.jpg
# []
# Elapsed time = 6.731521368026733[s]
# homer_simpson_31.jpg
# []
# Elapsed time = 7.186869859695435[s]
# homer_simpson_32.jpg
# []
# Elapsed time = 8.495910882949829[s]
# homer_simpson_33.jpg
# []
# Elapsed time = 7.563249588012695[s]
# homer_simpson_34.jpg
# []
# Elapsed time = 7.8699259757995605[s]
# homer_simpson_35.jpg
# []
# Elapsed time = 7.551041603088379[s]
# homer_simpson_36.jpg
# []
# Elapsed time = 7.940261363983154[s]
# homer_simpson_37.jpg
# []
# Elapsed time = 7.586699485778809[s]
# homer_simpson_38.jpg
# []
# Elapsed time = 7.82580304145813[s]
# homer_simpson_39.jpg
# []
# Elapsed time = 8.594148874282837[s]
# homer_simpson_4.jpg
# []
# Elapsed time = 7.857394218444824[s]
# homer_simpson_40.jpg
# []
# Elapsed time = 7.774613380432129[s]
# homer_simpson_41.jpg
# []
# Elapsed time = 6.686901807785034[s]
# homer_simpson_42.jpg
# []
# Elapsed time = 7.7232582569122314[s]
# homer_simpson_43.jpg
# []
# Elapsed time = 7.694619655609131[s]
# homer_simpson_44.jpg
# []
# Elapsed time = 7.796612977981567[s]
# homer_simpson_45.jpg
# []
# Elapsed time = 8.102223634719849[s]
# homer_simpson_46.jpg
# []
# Elapsed time = 7.8893256187438965[s]
# homer_simpson_47.jpg
# []
# Elapsed time = 7.963531970977783[s]
# homer_simpson_48.jpg
# []
# Elapsed time = 6.561987638473511[s]
# homer_simpson_49.jpg
# []
# Elapsed time = 7.485166311264038[s]
# homer_simpson_5.jpg
# []
# Elapsed time = 7.582674264907837[s]
# homer_simpson_6.jpg
# []
# Elapsed time = 7.516571521759033[s]
# homer_simpson_7.jpg
# []
# Elapsed time = 6.799542665481567[s]
# homer_simpson_8.jpg
# []
# Elapsed time = 6.679073810577393[s]
# homer_simpson_9.jpg
# []
# Elapsed time = 7.008447647094727[s]
# kent_brockman_0.jpg
# []
# Elapsed time = 7.116460084915161[s]
# kent_brockman_1.jpg
# []
# Elapsed time = 6.794660806655884[s]
# kent_brockman_10.jpg
# []
# Elapsed time = 7.502911329269409[s]
# kent_brockman_11.jpg
# []
# Elapsed time = 6.480534076690674[s]
# kent_brockman_12.jpg
# []
# Elapsed time = 5.522504568099976[s]
# kent_brockman_13.jpg
# []
# Elapsed time = 6.567714214324951[s]
# kent_brockman_14.jpg
# []
# Elapsed time = 6.92552638053894[s]
# kent_brockman_15.jpg
# []
# Elapsed time = 6.860265731811523[s]
# kent_brockman_16.jpg
# []
# Elapsed time = 6.742730140686035[s]
# kent_brockman_17.jpg
# []
# Elapsed time = 7.396584987640381[s]
# kent_brockman_18.jpg
# []
# Elapsed time = 6.628865957260132[s]
# kent_brockman_19.jpg
# []
# Elapsed time = 6.754684686660767[s]
# kent_brockman_2.jpg
# []
# Elapsed time = 6.373429536819458[s]
# kent_brockman_20.jpg
# []
# Elapsed time = 5.928781509399414[s]
# kent_brockman_21.jpg
# []
# Elapsed time = 6.699636459350586[s]
# kent_brockman_22.jpg
# []
# Elapsed time = 6.754523754119873[s]
# kent_brockman_23.jpg
# []
# Elapsed time = 5.8200602531433105[s]
# kent_brockman_24.jpg
# []
# Elapsed time = 8.750240325927734[s]
# kent_brockman_25.jpg
# []
# Elapsed time = 8.34522557258606[s]
# kent_brockman_26.jpg
# []
# Elapsed time = 9.242121458053589[s]
# kent_brockman_27.jpg
# []
# Elapsed time = 8.455580472946167[s]
# kent_brockman_28.jpg
# []
# Elapsed time = 8.279442310333252[s]
# kent_brockman_29.jpg
# []
# Elapsed time = 8.382965087890625[s]
# kent_brockman_3.jpg
# []
# Elapsed time = 7.877964019775391[s]
# kent_brockman_30.jpg
# []
# Elapsed time = 7.725014925003052[s]
# kent_brockman_31.jpg
# []
# Elapsed time = 7.758275985717773[s]
# kent_brockman_32.jpg
# []
# Elapsed time = 8.421599626541138[s]
# kent_brockman_33.jpg
# []
# Elapsed time = 6.633308172225952[s]
# kent_brockman_34.jpg
# []
# Elapsed time = 6.270758390426636[s]
# kent_brockman_35.jpg
# []
# Elapsed time = 6.389522552490234[s]
# kent_brockman_36.jpg
# []
# Elapsed time = 6.876635313034058[s]
# kent_brockman_37.jpg
# []
# Elapsed time = 6.69008994102478[s]
# kent_brockman_38.jpg
# []
# Elapsed time = 7.4876134395599365[s]
# kent_brockman_39.jpg
# []
# Elapsed time = 7.041834831237793[s]
# kent_brockman_4.jpg
# []
# Elapsed time = 6.7645041942596436[s]
# kent_brockman_40.jpg
# []
# Elapsed time = 6.2790749073028564[s]
# kent_brockman_41.jpg
# []
# Elapsed time = 5.837440729141235[s]
# kent_brockman_42.jpg
# []
# Elapsed time = 6.419219493865967[s]
# kent_brockman_43.jpg
# []
# Elapsed time = 6.755270481109619[s]
# kent_brockman_44.jpg
# []
# Elapsed time = 6.433729887008667[s]
# kent_brockman_45.jpg
# []
# Elapsed time = 7.053340196609497[s]
# kent_brockman_46.jpg
# []
# Elapsed time = 7.302475452423096[s]
# kent_brockman_47.jpg
# []
# Elapsed time = 8.108431816101074[s]
# kent_brockman_48.jpg
# []
# Elapsed time = 8.522881269454956[s]
# kent_brockman_49.jpg
# []
# Elapsed time = 7.9239113330841064[s]
# kent_brockman_5.jpg
# []
# Elapsed time = 6.906163454055786[s]
# kent_brockman_6.jpg
# []
# Elapsed time = 7.380247592926025[s]
# kent_brockman_7.jpg
# []
# Elapsed time = 7.830270767211914[s]
# kent_brockman_8.jpg
# []
# Elapsed time = 7.375110864639282[s]
# kent_brockman_9.jpg
# []
# Elapsed time = 7.5524303913116455[s]
# krusty_the_clown_0.jpg
# []
# Elapsed time = 7.9372241497039795[s]
# krusty_the_clown_1.jpg
# []
# Elapsed time = 7.234875917434692[s]
# krusty_the_clown_10.jpg
# []
# Elapsed time = 6.9672157764434814[s]
# krusty_the_clown_11.jpg
# []
# Elapsed time = 6.434412479400635[s]
# krusty_the_clown_12.jpg
# []
# Elapsed time = 6.749494791030884[s]
# krusty_the_clown_13.jpg
# []
# Elapsed time = 6.341972351074219[s]
# krusty_the_clown_14.jpg
# []
# Elapsed time = 6.659340143203735[s]
# krusty_the_clown_15.jpg
# []
# Elapsed time = 6.94919490814209[s]
# krusty_the_clown_16.jpg
# []
# Elapsed time = 6.584930658340454[s]
# krusty_the_clown_17.jpg
# []
# Elapsed time = 6.4836745262146[s]
# krusty_the_clown_18.jpg
# []
# Elapsed time = 7.04796290397644[s]
# krusty_the_clown_19.jpg
# []
# Elapsed time = 7.120185136795044[s]
# krusty_the_clown_2.jpg
# []
# Elapsed time = 6.216766119003296[s]
# krusty_the_clown_20.jpg
# []
# Elapsed time = 7.3768205642700195[s]
# krusty_the_clown_21.jpg
# []
# Elapsed time = 6.9009106159210205[s]
# krusty_the_clown_22.jpg
# []
# Elapsed time = 6.7713940143585205[s]
# krusty_the_clown_23.jpg
# []
# Elapsed time = 8.662675380706787[s]
# krusty_the_clown_24.jpg
# []
# Elapsed time = 6.588362216949463[s]
# krusty_the_clown_25.jpg
# []
# Elapsed time = 6.3470299243927[s]
# krusty_the_clown_26.jpg
# []
# Elapsed time = 6.118767261505127[s]
# krusty_the_clown_27.jpg
# []
# Elapsed time = 6.220080614089966[s]
# krusty_the_clown_28.jpg
# []
# Elapsed time = 6.1162803173065186[s]
# krusty_the_clown_29.jpg
# []
# Elapsed time = 7.456247091293335[s]
# krusty_the_clown_3.jpg
# []
# Elapsed time = 6.727868318557739[s]
# krusty_the_clown_30.jpg
# []
# Elapsed time = 6.631093740463257[s]
# krusty_the_clown_31.jpg
# []
# Elapsed time = 6.3135130405426025[s]
# krusty_the_clown_32.jpg
# []
# Elapsed time = 6.299616098403931[s]
# krusty_the_clown_33.jpg
# []
# Elapsed time = 6.993456125259399[s]
# krusty_the_clown_34.jpg
# []
# Elapsed time = 7.115549564361572[s]
# krusty_the_clown_35.jpg
# []
# Elapsed time = 6.138931751251221[s]
# krusty_the_clown_36.jpg
# []
# Elapsed time = 6.306399345397949[s]
# krusty_the_clown_37.jpg
# []
# Elapsed time = 6.74585747718811[s]
# krusty_the_clown_38.jpg
# []
# Elapsed time = 6.348304271697998[s]
# krusty_the_clown_39.jpg
# []
# Elapsed time = 6.5445451736450195[s]
# krusty_the_clown_4.jpg
# []
# Elapsed time = 6.032117128372192[s]
# krusty_the_clown_40.jpg
# []
# Elapsed time = 6.84769344329834[s]
# krusty_the_clown_41.jpg
# []
# Elapsed time = 6.022582769393921[s]
# krusty_the_clown_42.jpg
# []
# Elapsed time = 6.210305690765381[s]
# krusty_the_clown_43.jpg
# []
# Elapsed time = 6.219013452529907[s]
# krusty_the_clown_44.jpg
# []
# Elapsed time = 6.254603624343872[s]
# krusty_the_clown_45.jpg
# []
# Elapsed time = 6.1475830078125[s]
# krusty_the_clown_46.jpg
# []
# Elapsed time = 7.587995290756226[s]
# krusty_the_clown_47.jpg
# []
# Elapsed time = 7.877941370010376[s]
# krusty_the_clown_48.jpg
# []
# Elapsed time = 6.782852649688721[s]
# krusty_the_clown_49.jpg
# []
# Elapsed time = 6.308496952056885[s]
# krusty_the_clown_5.jpg
# []
# Elapsed time = 6.279094934463501[s]
# krusty_the_clown_6.jpg
# []
# Elapsed time = 6.6545515060424805[s]
# krusty_the_clown_7.jpg
# []
# Elapsed time = 6.161472797393799[s]
# krusty_the_clown_8.jpg
# []
# Elapsed time = 5.930872917175293[s]
# krusty_the_clown_9.jpg
# []
# Elapsed time = 5.989586114883423[s]
# lenny_leonard_0.jpg
# []
# Elapsed time = 6.257590055465698[s]
# lenny_leonard_1.jpg
# []
# Elapsed time = 8.69348692893982[s]
# lenny_leonard_10.jpg
# []
# Elapsed time = 9.302560091018677[s]
# lenny_leonard_11.jpg
# []
# Elapsed time = 8.430995225906372[s]
# lenny_leonard_12.jpg
# []
# Elapsed time = 8.236260890960693[s]
# lenny_leonard_13.jpg
# []
# Elapsed time = 8.462141036987305[s]
# lenny_leonard_14.jpg
# []
# Elapsed time = 7.753208875656128[s]
# lenny_leonard_15.jpg
# []
# Elapsed time = 7.0832695960998535[s]
# lenny_leonard_16.jpg
# []
# Elapsed time = 7.7855095863342285[s]
# lenny_leonard_17.jpg
# []
# Elapsed time = 7.765453815460205[s]
# lenny_leonard_18.jpg
# []
# Elapsed time = 10.902846097946167[s]
# lenny_leonard_19.jpg
# []
# Elapsed time = 8.263254880905151[s]
# lenny_leonard_2.jpg
# []
# Elapsed time = 6.183436632156372[s]
# lenny_leonard_20.jpg
# []
# Elapsed time = 8.692942142486572[s]
# lenny_leonard_21.jpg
# []
# Elapsed time = 8.045719146728516[s]
# lenny_leonard_22.jpg
# []
# Elapsed time = 7.7502665519714355[s]
# lenny_leonard_23.jpg
# []
# Elapsed time = 7.922594308853149[s]
# lenny_leonard_24.jpg
# []
# Elapsed time = 7.468010425567627[s]
# lenny_leonard_25.jpg
# []
# Elapsed time = 7.554067134857178[s]
# lenny_leonard_26.jpg
# []
# Elapsed time = 8.50428032875061[s]
# lenny_leonard_27.jpg
# []
# Elapsed time = 10.5785493850708[s]
# lenny_leonard_28.jpg
# []
# Elapsed time = 9.242541074752808[s]
# lenny_leonard_29.jpg
# []
# Elapsed time = 8.510705947875977[s]
# lenny_leonard_3.jpg
# []
# Elapsed time = 7.2110161781311035[s]
# lenny_leonard_30.jpg
# []
# Elapsed time = 8.664990425109863[s]
# lenny_leonard_31.jpg
# []
# Elapsed time = 9.725263357162476[s]
# lenny_leonard_32.jpg
# []
# Elapsed time = 9.537898063659668[s]
# lenny_leonard_33.jpg
# []
# Elapsed time = 9.580265283584595[s]
# lenny_leonard_34.jpg
# []
# Elapsed time = 8.769387006759644[s]
# lenny_leonard_35.jpg
# []
# Elapsed time = 8.451927900314331[s]
# lenny_leonard_36.jpg
# []
# Elapsed time = 7.9013450145721436[s]
# lenny_leonard_37.jpg
# []
# Elapsed time = 8.364067077636719[s]
# lenny_leonard_38.jpg
# []
# Elapsed time = 7.1067187786102295[s]
# lenny_leonard_39.jpg
# []
# Elapsed time = 8.18794059753418[s]
# lenny_leonard_4.jpg
# []
# Elapsed time = 7.267240524291992[s]
# lenny_leonard_40.jpg
# []
# Elapsed time = 7.447023153305054[s]
# lenny_leonard_41.jpg
# []
# Elapsed time = 7.762920379638672[s]
# lenny_leonard_42.jpg
# []
# Elapsed time = 7.788517713546753[s]
# lenny_leonard_43.jpg
# []
# Elapsed time = 7.585429430007935[s]
# lenny_leonard_44.jpg
# []
# Elapsed time = 6.829844951629639[s]
# lenny_leonard_45.jpg
# []
# Elapsed time = 6.994454622268677[s]
# lenny_leonard_46.jpg
# []
# Elapsed time = 6.950779914855957[s]
# lenny_leonard_47.jpg
# []
# Elapsed time = 7.452236652374268[s]
# lenny_leonard_48.jpg
# []
# Elapsed time = 8.161227941513062[s]
# lenny_leonard_49.jpg
# []
# Elapsed time = 7.6503424644470215[s]
# lenny_leonard_5.jpg
# []
# Elapsed time = 11.97261643409729[s]
# lenny_leonard_6.jpg
# []
# Elapsed time = 11.826265335083008[s]
# lenny_leonard_7.jpg
# []
# Elapsed time = 5.296742916107178[s]
# lenny_leonard_8.jpg
# []
# Elapsed time = 5.2112157344818115[s]
# lenny_leonard_9.jpg
# []
# Elapsed time = 5.52709698677063[s]
# lisa_simpson_0.jpg
# []
# Elapsed time = 4.786487340927124[s]
# lisa_simpson_1.jpg
# []
# Elapsed time = 5.056311130523682[s]
# lisa_simpson_10.jpg
# []
# Elapsed time = 5.162461042404175[s]
# lisa_simpson_11.jpg
# []
# Elapsed time = 5.443666219711304[s]
# lisa_simpson_12.jpg
# []
# Elapsed time = 5.746654748916626[s]
# lisa_simpson_13.jpg
# []
# Elapsed time = 5.399380922317505[s]
# lisa_simpson_14.jpg
# []
# Elapsed time = 5.13070821762085[s]
# lisa_simpson_15.jpg
# []
# Elapsed time = 4.885404109954834[s]
# lisa_simpson_16.jpg
# []
# Elapsed time = 5.037681818008423[s]
# lisa_simpson_17.jpg
# []
# Elapsed time = 4.845274925231934[s]
# lisa_simpson_18.jpg
# []
# Elapsed time = 4.913077116012573[s]
# lisa_simpson_19.jpg
# []
# Elapsed time = 4.799186944961548[s]
# lisa_simpson_2.jpg
# []
# Elapsed time = 4.984343528747559[s]
# lisa_simpson_20.jpg
# []
# Elapsed time = 4.899663925170898[s]
# lisa_simpson_21.jpg
# []
# Elapsed time = 4.8723225593566895[s]
# lisa_simpson_22.jpg
# []
# Elapsed time = 4.743258237838745[s]
# lisa_simpson_23.jpg
# []
# Elapsed time = 4.94814658164978[s]
# lisa_simpson_24.jpg
# []
# Elapsed time = 4.961268663406372[s]
# lisa_simpson_25.jpg
# []
# Elapsed time = 5.702312231063843[s]
# lisa_simpson_26.jpg
# []
# Elapsed time = 6.231377124786377[s]
# lisa_simpson_27.jpg
# []
# Elapsed time = 5.419284820556641[s]
# lisa_simpson_28.jpg
# []
# Elapsed time = 4.995319843292236[s]
# lisa_simpson_29.jpg
# []
# Elapsed time = 4.507614374160767[s]
# lisa_simpson_3.jpg
# []
# Elapsed time = 4.10012149810791[s]
# lisa_simpson_30.jpg
# []
# Elapsed time = 3.986356019973755[s]
# lisa_simpson_31.jpg
# []
# Elapsed time = 5.100939512252808[s]
# lisa_simpson_32.jpg
# []
# Elapsed time = 4.825421333312988[s]
# lisa_simpson_33.jpg
# []
# Elapsed time = 5.300012588500977[s]
# lisa_simpson_34.jpg
# []
# Elapsed time = 5.557309627532959[s]
# lisa_simpson_35.jpg
# []
# Elapsed time = 5.263779401779175[s]
# lisa_simpson_36.jpg
# []
# Elapsed time = 5.029012203216553[s]
# lisa_simpson_37.jpg
# []
# Elapsed time = 5.365888357162476[s]
# lisa_simpson_38.jpg
# []
# Elapsed time = 5.520448207855225[s]
# lisa_simpson_39.jpg
# []
# Elapsed time = 5.174314022064209[s]
# lisa_simpson_4.jpg
# []
# Elapsed time = 4.498074769973755[s]
# lisa_simpson_40.jpg
# []
# Elapsed time = 4.652716159820557[s]
# lisa_simpson_41.jpg
# []
# Elapsed time = 5.232968807220459[s]
# lisa_simpson_42.jpg
# []
# Elapsed time = 4.579964876174927[s]
# lisa_simpson_43.jpg
# []
# Elapsed time = 3.7023608684539795[s]
# lisa_simpson_44.jpg
# []
# Elapsed time = 3.474196434020996[s]
# lisa_simpson_45.jpg
# []
# Elapsed time = 3.5186338424682617[s]
# lisa_simpson_46.jpg
# []
# Elapsed time = 3.717440366744995[s]
# lisa_simpson_47.jpg
# []
# Elapsed time = 3.8527565002441406[s]
# lisa_simpson_48.jpg
# []
# Elapsed time = 3.7031409740448[s]
# lisa_simpson_49.jpg
# []
# Elapsed time = 5.06485652923584[s]
# lisa_simpson_5.jpg
# []
# Elapsed time = 5.05490779876709[s]
# lisa_simpson_6.jpg
# []
# Elapsed time = 5.380727767944336[s]
# lisa_simpson_7.jpg
# []
# Elapsed time = 5.44085955619812[s]
# lisa_simpson_8.jpg
# []
# Elapsed time = 4.869760513305664[s]
# lisa_simpson_9.jpg
# []
# Elapsed time = 5.302311182022095[s]
# marge_simpson_0.jpg
# []
# Elapsed time = 5.899187326431274[s]
# marge_simpson_1.jpg
# []
# Elapsed time = 5.581844091415405[s]
# marge_simpson_10.jpg
# []
# Elapsed time = 5.187991380691528[s]
# marge_simpson_11.jpg
# []
# Elapsed time = 5.542033433914185[s]
# marge_simpson_12.jpg
# []
# Elapsed time = 5.0885560512542725[s]
# marge_simpson_13.jpg
# []
# Elapsed time = 5.281761646270752[s]
# marge_simpson_14.jpg
# []
# Elapsed time = 5.646195650100708[s]
# marge_simpson_15.jpg
# []
# Elapsed time = 5.171618700027466[s]
# marge_simpson_16.jpg
# []
# Elapsed time = 5.867807388305664[s]
# marge_simpson_17.jpg
# []
# Elapsed time = 6.303011894226074[s]
# marge_simpson_18.jpg
# []
# Elapsed time = 6.358669996261597[s]
# marge_simpson_19.jpg
# []
# Elapsed time = 6.020007610321045[s]
# marge_simpson_2.jpg
# []
# Elapsed time = 5.4120094776153564[s]
# marge_simpson_20.jpg
# []
# Elapsed time = 5.430396556854248[s]
# marge_simpson_21.jpg
# []
# Elapsed time = 5.467804193496704[s]
# marge_simpson_22.jpg
# []
# Elapsed time = 5.9034295082092285[s]
# marge_simpson_23.jpg
# []
# Elapsed time = 5.494423866271973[s]
# marge_simpson_24.jpg
# []
# Elapsed time = 5.397756576538086[s]
# marge_simpson_25.jpg
# []
# Elapsed time = 5.16453742980957[s]
# marge_simpson_26.jpg
# []
# Elapsed time = 5.514230012893677[s]
# marge_simpson_27.jpg
# []
# Elapsed time = 7.389980316162109[s]
# marge_simpson_28.jpg
# []
# Elapsed time = 6.165621519088745[s]
# marge_simpson_29.jpg
# []
# Elapsed time = 4.952519655227661[s]
# marge_simpson_3.jpg
# []
# Elapsed time = 5.269284009933472[s]
# marge_simpson_30.jpg
# []
# Elapsed time = 4.95294713973999[s]
# marge_simpson_31.jpg
# []
# Elapsed time = 5.345536708831787[s]
# marge_simpson_32.jpg
# []
# Elapsed time = 4.944596290588379[s]
# marge_simpson_33.jpg
# []
# Elapsed time = 5.328652381896973[s]
# marge_simpson_34.jpg
# []
# Elapsed time = 4.944051742553711[s]
# marge_simpson_35.jpg
# []
# Elapsed time = 4.65967583656311[s]
# marge_simpson_36.jpg
# []
# Elapsed time = 5.194754123687744[s]
# marge_simpson_37.jpg
# []
# Elapsed time = 4.637580633163452[s]
# marge_simpson_38.jpg
# []
# Elapsed time = 4.815605640411377[s]
# marge_simpson_39.jpg
# []
# Elapsed time = 5.369295358657837[s]
# marge_simpson_4.jpg
# []
# Elapsed time = 4.862473964691162[s]
# marge_simpson_40.jpg
# []
# Elapsed time = 4.541281461715698[s]
# marge_simpson_41.jpg
# []
# Elapsed time = 6.108575344085693[s]
# marge_simpson_42.jpg
# []
# Elapsed time = 5.821746110916138[s]
# marge_simpson_43.jpg
# []
# Elapsed time = 6.213862895965576[s]
# marge_simpson_44.jpg
# []
# Elapsed time = 5.874021768569946[s]
# marge_simpson_45.jpg
# []
# Elapsed time = 4.400434255599976[s]
# marge_simpson_46.jpg
# []
# Elapsed time = 4.20595121383667[s]
# marge_simpson_47.jpg
# []
# Elapsed time = 4.229361534118652[s]
# marge_simpson_48.jpg
# []
# Elapsed time = 4.173799514770508[s]
# marge_simpson_49.jpg
# []
# Elapsed time = 4.03603720664978[s]
# marge_simpson_5.jpg
# []
# Elapsed time = 4.300870418548584[s]
# marge_simpson_6.jpg
# []
# Elapsed time = 4.422985553741455[s]
# marge_simpson_7.jpg
# []
# Elapsed time = 4.305517673492432[s]
# marge_simpson_8.jpg
# []
# Elapsed time = 4.26629114151001[s]
# marge_simpson_9.jpg
# []
# Elapsed time = 4.3131585121154785[s]
# mayor_quimby_0.jpg
# []
# Elapsed time = 4.34049391746521[s]
# mayor_quimby_1.jpg
# []
# Elapsed time = 4.4713804721832275[s]
# mayor_quimby_10.jpg
# []
# Elapsed time = 4.849006175994873[s]
# mayor_quimby_11.jpg
# []
# Elapsed time = 4.523301124572754[s]
# mayor_quimby_12.jpg
# []
# Elapsed time = 4.146921157836914[s]
# mayor_quimby_13.jpg
# []
# Elapsed time = 4.139920234680176[s]
# mayor_quimby_14.jpg
# []
# Elapsed time = 4.319865942001343[s]
# mayor_quimby_15.jpg
# []
# Elapsed time = 4.267225980758667[s]
# mayor_quimby_16.jpg
# []
# Elapsed time = 4.263776063919067[s]
# mayor_quimby_17.jpg
# []
# Elapsed time = 4.255484580993652[s]
# mayor_quimby_18.jpg
# []
# Elapsed time = 4.227367162704468[s]
# mayor_quimby_19.jpg
# []
# Elapsed time = 4.206958532333374[s]
# mayor_quimby_2.jpg
# []
# Elapsed time = 4.476512908935547[s]
# mayor_quimby_20.jpg
# []
# Elapsed time = 4.757301568984985[s]
# mayor_quimby_21.jpg
# []
# Elapsed time = 4.366674900054932[s]
# mayor_quimby_22.jpg
# []
# Elapsed time = 4.713505029678345[s]
# mayor_quimby_23.jpg
# []
# Elapsed time = 4.6482367515563965[s]
# mayor_quimby_24.jpg
# []
# Elapsed time = 4.340245246887207[s]
# mayor_quimby_25.jpg
# []
# Elapsed time = 4.474689483642578[s]
# mayor_quimby_26.jpg
# []
# Elapsed time = 4.394117832183838[s]
# mayor_quimby_27.jpg
# []
# Elapsed time = 4.306461811065674[s]
# mayor_quimby_28.jpg
# []
# Elapsed time = 4.2493720054626465[s]
# mayor_quimby_29.jpg
# []
# Elapsed time = 4.345883846282959[s]
# mayor_quimby_3.jpg
# []
# Elapsed time = 4.3717756271362305[s]
# mayor_quimby_30.jpg
# []
# Elapsed time = 4.328913927078247[s]
# mayor_quimby_31.jpg
# []
# Elapsed time = 4.236748456954956[s]
# mayor_quimby_32.jpg
# []
# Elapsed time = 4.262807369232178[s]
# mayor_quimby_33.jpg
# []
# Elapsed time = 4.276782512664795[s]
# mayor_quimby_34.jpg
# []
# Elapsed time = 4.278153419494629[s]
# mayor_quimby_35.jpg
# []
# Elapsed time = 4.173707485198975[s]
# mayor_quimby_36.jpg
# []
# Elapsed time = 4.206871747970581[s]
# mayor_quimby_37.jpg
# []
# Elapsed time = 4.228150129318237[s]
# mayor_quimby_38.jpg
# []
# Elapsed time = 4.142888784408569[s]
# mayor_quimby_39.jpg
# []
# Elapsed time = 4.181953191757202[s]
# mayor_quimby_4.jpg
# []
# Elapsed time = 4.340713739395142[s]
# mayor_quimby_40.jpg
# []
# Elapsed time = 4.379028797149658[s]
# mayor_quimby_41.jpg
# []
# Elapsed time = 4.087591886520386[s]
# mayor_quimby_42.jpg
# []
# Elapsed time = 4.146771669387817[s]
# mayor_quimby_43.jpg
# []
# Elapsed time = 4.0325775146484375[s]
# mayor_quimby_44.jpg
# []
# Elapsed time = 4.2429773807525635[s]
# mayor_quimby_45.jpg
# []
# Elapsed time = 4.264768362045288[s]
# mayor_quimby_46.jpg
# []
# Elapsed time = 4.390598297119141[s]
# mayor_quimby_47.jpg
# []
# Elapsed time = 4.226539373397827[s]
# mayor_quimby_48.jpg
# []
# Elapsed time = 8.414206981658936[s]
# mayor_quimby_49.jpg
# []
# Elapsed time = 6.177855014801025[s]
# mayor_quimby_5.jpg
# []
# Elapsed time = 5.106666326522827[s]
# mayor_quimby_6.jpg
# []
# Elapsed time = 5.400635242462158[s]
# mayor_quimby_7.jpg
# []
# Elapsed time = 5.0977559089660645[s]
# mayor_quimby_8.jpg
# []
# Elapsed time = 5.094768285751343[s]
# mayor_quimby_9.jpg
# []
# Elapsed time = 4.766108512878418[s]
# milhouse_van_houten_0.jpg
# []
# Elapsed time = 5.126179218292236[s]
# milhouse_van_houten_1.jpg
# []
# Elapsed time = 4.8778462409973145[s]
# milhouse_van_houten_10.jpg
# []
# Elapsed time = 4.827266693115234[s]
# milhouse_van_houten_11.jpg
# []
# Elapsed time = 4.886781692504883[s]
# milhouse_van_houten_12.jpg
# []
# Elapsed time = 4.814582586288452[s]
# milhouse_van_houten_13.jpg
# []
# Elapsed time = 4.770663261413574[s]
# milhouse_van_houten_14.jpg
# []
# Elapsed time = 4.692018032073975[s]
# milhouse_van_houten_15.jpg
# []
# Elapsed time = 8.237772703170776[s]
# milhouse_van_houten_16.jpg
# []
# Elapsed time = 7.583059787750244[s]
# milhouse_van_houten_17.jpg
# []
# Elapsed time = 7.030907154083252[s]
# milhouse_van_houten_18.jpg
# []
# Elapsed time = 5.69406795501709[s]
# milhouse_van_houten_19.jpg
# []
# Elapsed time = 4.93823766708374[s]
# milhouse_van_houten_20.jpg
# []
# Elapsed time = 5.236940145492554[s]
# milhouse_van_houten_21.jpg
# []
# Elapsed time = 5.506109952926636[s]
# milhouse_van_houten_22.jpg
# []
# Elapsed time = 4.990744352340698[s]
# milhouse_van_houten_23.jpg
# []
# Elapsed time = 4.754643678665161[s]
# milhouse_van_houten_24.jpg
# []
# Elapsed time = 4.791024446487427[s]
# milhouse_van_houten_25.jpg
# []
# Elapsed time = 4.866154432296753[s]
# milhouse_van_houten_26.jpg
# []
# Elapsed time = 4.780911684036255[s]
# milhouse_van_houten_27.jpg
# []
# Elapsed time = 5.2494096755981445[s]
# milhouse_van_houten_28.jpg
# []
# Elapsed time = 4.8847174644470215[s]
# milhouse_van_houten_29.jpg
# []
# Elapsed time = 4.8254125118255615[s]
# milhouse_van_houten_3.jpg
# []
# Elapsed time = 4.72378945350647[s]
# milhouse_van_houten_30.jpg
# []
# Elapsed time = 4.610746622085571[s]
# milhouse_van_houten_31.jpg
# []
# Elapsed time = 4.786518335342407[s]
# milhouse_van_houten_32.jpg
# []
# Elapsed time = 5.126860857009888[s]
# milhouse_van_houten_33.jpg
# []
# Elapsed time = 4.817580699920654[s]
# milhouse_van_houten_34.jpg
# []
# Elapsed time = 4.831670045852661[s]
# milhouse_van_houten_35.jpg
# []
# Elapsed time = 4.865870475769043[s]
# milhouse_van_houten_36.jpg
# []
# Elapsed time = 4.815522193908691[s]
# milhouse_van_houten_37.jpg
# []
# Elapsed time = 4.8821024894714355[s]
# milhouse_van_houten_38.jpg
# []
# Elapsed time = 5.2775068283081055[s]
# milhouse_van_houten_39.jpg
# []
# Elapsed time = 4.8842034339904785[s]
# milhouse_van_houten_4.jpg
# []
# Elapsed time = 4.983174085617065[s]
# milhouse_van_houten_40.jpg
# []
# Elapsed time = 5.670944690704346[s]
# milhouse_van_houten_41.jpg
# []
# Elapsed time = 4.890631198883057[s]
# milhouse_van_houten_42.jpg
# []
# Elapsed time = 5.505849838256836[s]
# milhouse_van_houten_43.jpg
# []
# Elapsed time = 5.88090181350708[s]
# milhouse_van_houten_44.jpg
# []
# Elapsed time = 5.664881467819214[s]
# milhouse_van_houten_45.jpg
# []
# Elapsed time = 6.442220211029053[s]
# milhouse_van_houten_46.jpg
# []
# Elapsed time = 5.611177206039429[s]
# milhouse_van_houten_47.jpg
# []
# Elapsed time = 5.3645641803741455[s]
# milhouse_van_houten_48.jpg
# []
# Elapsed time = 5.712937355041504[s]
# milhouse_van_houten_49.jpg
# []
# Elapsed time = 5.544313669204712[s]
# milhouse_van_houten_5.jpg
# []
# Elapsed time = 5.793124437332153[s]
# milhouse_van_houten_6.jpg
# []
# Elapsed time = 6.13445520401001[s]
# milhouse_van_houten_7.jpg
# []
# Elapsed time = 5.981454610824585[s]
# milhouse_van_houten_8.jpg
# []
# Elapsed time = 5.949617147445679[s]
# milhouse_van_houten_9.jpg
# []
# Elapsed time = 5.839405059814453[s]
# moe_szyslak_0.jpg
# []
# Elapsed time = 5.058287143707275[s]
# moe_szyslak_1.jpg
# []
# Elapsed time = 4.854216814041138[s]
# moe_szyslak_10.jpg
# []
# Elapsed time = 4.593430995941162[s]
# moe_szyslak_11.jpg
# []
# Elapsed time = 4.848403692245483[s]
# moe_szyslak_12.jpg
# []
# Elapsed time = 4.926820993423462[s]
# moe_szyslak_13.jpg
# []
# Elapsed time = 4.606689929962158[s]
# moe_szyslak_14.jpg
# []
# Elapsed time = 4.949840784072876[s]
# moe_szyslak_15.jpg
# []
# Elapsed time = 5.2432637214660645[s]
# moe_szyslak_16.jpg
# []
# Elapsed time = 6.326569080352783[s]
# moe_szyslak_17.jpg
# []
# Elapsed time = 5.6047210693359375[s]
# moe_szyslak_18.jpg
# []
# Elapsed time = 6.445998907089233[s]
# moe_szyslak_19.jpg
# []
# Elapsed time = 5.905871868133545[s]
# moe_szyslak_2.jpg
# []
# Elapsed time = 5.600265264511108[s]
# moe_szyslak_20.jpg
# []
# Elapsed time = 4.749011039733887[s]
# moe_szyslak_21.jpg
# []
# Elapsed time = 5.234330892562866[s]
# moe_szyslak_22.jpg
# []
# Elapsed time = 5.4554266929626465[s]
# moe_szyslak_23.jpg
# []
# Elapsed time = 5.507120132446289[s]
# moe_szyslak_24.jpg
# []
# Elapsed time = 6.393803596496582[s]
# moe_szyslak_25.jpg
# []
# Elapsed time = 5.850651979446411[s]
# moe_szyslak_26.jpg
# []
# Elapsed time = 5.468027830123901[s]
# moe_szyslak_27.jpg
# []
# Elapsed time = 5.348332643508911[s]
# moe_szyslak_28.jpg
# []
# Elapsed time = 5.352970600128174[s]
# moe_szyslak_29.jpg
# []
# Elapsed time = 5.037685394287109[s]
# moe_szyslak_3.jpg
# []
# Elapsed time = 5.80617880821228[s]
# moe_szyslak_30.jpg
# []
# Elapsed time = 7.8990256786346436[s]
# moe_szyslak_31.jpg
# []
# Elapsed time = 7.891312837600708[s]
# moe_szyslak_32.jpg
# []
# Elapsed time = 8.008766174316406[s]
# moe_szyslak_33.jpg
# []
# Elapsed time = 7.949360370635986[s]
# moe_szyslak_34.jpg
# []
# Elapsed time = 7.919020414352417[s]
# moe_szyslak_35.jpg
# []
# ...
# ned_flanders_4.jpg
# []
# Elapsed time = 5.465197801589966[s]
# ned_flanders_40.jpg
# []
# Elapsed time = 5.351105690002441[s]
# ned_flanders_41.jpg
# []
# Elapsed time = 3.990274429321289[s]
# ned_flanders_42.jpg
# []
# Elapsed time = 3.37556529045105[s]
# ned_flanders_43.jpg
# []
# Elapsed time = 3.4841134548187256[s]
# ned_flanders_44.jpg
# []
# Elapsed time = 3.5095112323760986[s]
# ned_flanders_46.jpg
# []
# Elapsed time = 3.707186222076416[s]
# ned_flanders_47.jpg
# []
# Elapsed time = 3.483083724975586[s]
# ned_flanders_48.jpg
# []
# Elapsed time = 3.501579761505127[s]
# ned_flanders_49.jpg
# []
# Elapsed time = 3.4046332836151123[s]
# ned_flanders_5.jpg
# []
# Elapsed time = 3.6202893257141113[s]
# ned_flanders_6.jpg
# []
# Elapsed time = 3.3958616256713867[s]
# ned_flanders_7.jpg
# []
# Elapsed time = 3.5618374347686768[s]
# ned_flanders_8.jpg
# []
# Elapsed time = 3.3072774410247803[s]
# ned_flanders_9.jpg
# []
# Elapsed time = 3.1071460247039795[s]
# nelson_muntz_0.jpg
# []
# Elapsed time = 3.1904709339141846[s]
# nelson_muntz_1.jpg
# []
# Elapsed time = 3.0372140407562256[s]
# nelson_muntz_10.jpg
# []
# Elapsed time = 3.094071626663208[s]
# nelson_muntz_11.jpg
# []
# Elapsed time = 3.035884380340576[s]
# nelson_muntz_12.jpg
# []
# Elapsed time = 3.0266289710998535[s]
# nelson_muntz_13.jpg
# []
# Elapsed time = 3.178823709487915[s]
# nelson_muntz_14.jpg
# []
# Elapsed time = 3.137552499771118[s]
# nelson_muntz_15.jpg
# []
# Elapsed time = 3.1080808639526367[s]
# nelson_muntz_16.jpg
# []
# Elapsed time = 3.313448429107666[s]
# nelson_muntz_17.jpg
# []
# Elapsed time = 3.415834903717041[s]
# nelson_muntz_18.jpg
# []
# Elapsed time = 3.173088550567627[s]
# nelson_muntz_19.jpg
# []
# Elapsed time = 3.3488824367523193[s]
# nelson_muntz_2.jpg
# []
# Elapsed time = 3.2988152503967285[s]
# nelson_muntz_20.jpg
# []
# Elapsed time = 3.2231006622314453[s]
# nelson_muntz_21.jpg
# []
# Elapsed time = 3.2025394439697266[s]
# nelson_muntz_22.jpg
# []
# Elapsed time = 3.1215386390686035[s]
# nelson_muntz_23.jpg
# []
# Elapsed time = 3.3343589305877686[s]
# nelson_muntz_24.jpg
# []
# Elapsed time = 3.526120185852051[s]
# nelson_muntz_25.jpg
# []
# Elapsed time = 3.4826605319976807[s]
# nelson_muntz_26.jpg
# []
# Elapsed time = 3.1132304668426514[s]
# nelson_muntz_27.jpg
# []
# Elapsed time = 3.105719804763794[s]
# nelson_muntz_28.jpg
# []
# Elapsed time = 3.061042308807373[s]
# nelson_muntz_29.jpg
# []
# Elapsed time = 3.1531314849853516[s]
# nelson_muntz_3.jpg
# []
# Elapsed time = 3.1058108806610107[s]
# nelson_muntz_30.jpg
# []
# Elapsed time = 3.1274960041046143[s]
# nelson_muntz_31.jpg
# []
# Elapsed time = 3.1176462173461914[s]
# nelson_muntz_32.jpg
# []
# Elapsed time = 3.163067579269409[s]
# nelson_muntz_33.jpg
# []
# Elapsed time = 3.1226587295532227[s]
# nelson_muntz_34.jpg
# []
# Elapsed time = 3.190793514251709[s]
# nelson_muntz_35.jpg
# []
# Elapsed time = 3.1700057983398438[s]
# nelson_muntz_36.jpg
# []
# Elapsed time = 3.1477890014648438[s]
# nelson_muntz_37.jpg
# []
# Elapsed time = 3.1515676975250244[s]
# nelson_muntz_38.jpg
# []
# Elapsed time = 3.0978593826293945[s]
# nelson_muntz_39.jpg
# []
# Elapsed time = 3.226593494415283[s]
# nelson_muntz_4.jpg
# []
# Elapsed time = 3.0757551193237305[s]
# nelson_muntz_40.jpg
# []
# Elapsed time = 3.172424554824829[s]
# nelson_muntz_41.jpg
# []
# Elapsed time = 3.1989481449127197[s]
# nelson_muntz_42.jpg
# []
# Elapsed time = 3.2826826572418213[s]
# nelson_muntz_43.jpg
# []
# Elapsed time = 3.1381890773773193[s]
# nelson_muntz_44.jpg
# []
# Elapsed time = 3.1539225578308105[s]
# nelson_muntz_45.jpg
# []
# Elapsed time = 3.122260332107544[s]
# nelson_muntz_46.jpg
# []
# Elapsed time = 3.148392677307129[s]
# nelson_muntz_47.jpg
# []
# Elapsed time = 3.0485196113586426[s]
# nelson_muntz_48.jpg
# []
# Elapsed time = 3.052385091781616[s]
# nelson_muntz_49.jpg
# []
# Elapsed time = 3.266533851623535[s]
# nelson_muntz_5.jpg
# []
# Elapsed time = 3.4485433101654053[s]
# nelson_muntz_6.jpg
# []
# Elapsed time = 3.6247973442077637[s]
# nelson_muntz_7.jpg
# []
# Elapsed time = 3.4676311016082764[s]
# nelson_muntz_8.jpg
# []
# Elapsed time = 3.259265184402466[s]
# nelson_muntz_9.jpg
# []
# Elapsed time = 3.196460008621216[s]
# principal_skinner_0.jpg
# []
# Elapsed time = 3.2686238288879395[s]
# principal_skinner_1.jpg
# []
# Elapsed time = 3.2532155513763428[s]
# principal_skinner_10.jpg
# []
# Elapsed time = 3.2393295764923096[s]
# principal_skinner_11.jpg
# []
# Elapsed time = 3.4466538429260254[s]
# principal_skinner_12.jpg
# []
# Elapsed time = 3.5731935501098633[s]
# principal_skinner_13.jpg
# []
# Elapsed time = 3.660597324371338[s]
# principal_skinner_14.jpg
# []
# Elapsed time = 3.6090831756591797[s]
# principal_skinner_15.jpg
# []
# Elapsed time = 3.479769706726074[s]
# principal_skinner_16.jpg
# []
# Elapsed time = 3.175731897354126[s]
# principal_skinner_17.jpg
# []
# Elapsed time = 3.145808219909668[s]
# principal_skinner_18.jpg
# []
# Elapsed time = 3.311129331588745[s]
# principal_skinner_19.jpg
# []
# Elapsed time = 3.371819019317627[s]
# principal_skinner_2.jpg
# []
# Elapsed time = 3.1657326221466064[s]
# principal_skinner_20.jpg
# []
# Elapsed time = 3.171717643737793[s]
# principal_skinner_21.jpg
# []
# Elapsed time = 3.1727137565612793[s]
# principal_skinner_22.jpg
# []
# Elapsed time = 3.05635929107666[s]
# principal_skinner_23.jpg
# []
# Elapsed time = 3.085097074508667[s]
# principal_skinner_24.jpg
# []
# Elapsed time = 3.096658706665039[s]
# principal_skinner_25.jpg
# []
# Elapsed time = 3.1174631118774414[s]
# principal_skinner_26.jpg
# []
# Elapsed time = 3.073671340942383[s]
# principal_skinner_27.jpg
# []
# Elapsed time = 3.3337883949279785[s]
# principal_skinner_28.jpg
# []
# Elapsed time = 3.420461654663086[s]
# principal_skinner_29.jpg
# []
# Elapsed time = 3.5348260402679443[s]
# principal_skinner_3.jpg
# []
# Elapsed time = 3.079939126968384[s]
# principal_skinner_30.jpg
# []
# Elapsed time = 3.065666913986206[s]
# principal_skinner_31.jpg
# []
# Elapsed time = 3.125873327255249[s]
# principal_skinner_32.jpg
# []
# Elapsed time = 3.272336721420288[s]
# principal_skinner_33.jpg
# []
# Elapsed time = 3.233304262161255[s]
# principal_skinner_34.jpg
# []
# Elapsed time = 3.1983609199523926[s]
# principal_skinner_35.jpg
# []
# Elapsed time = 3.150467872619629[s]
# principal_skinner_36.jpg
# []
# Elapsed time = 3.196211099624634[s]
# principal_skinner_37.jpg
# []
# Elapsed time = 3.1317083835601807[s]
# principal_skinner_38.jpg
# []
# Elapsed time = 3.14497709274292[s]
# principal_skinner_39.jpg
# []
# Elapsed time = 3.1499180793762207[s]
# principal_skinner_4.jpg
# []
# Elapsed time = 3.176558256149292[s]
# principal_skinner_40.jpg
# []
# Elapsed time = 3.0959715843200684[s]
# principal_skinner_41.jpg
# []
# Elapsed time = 3.204594135284424[s]
# principal_skinner_42.jpg
# []
# Elapsed time = 3.1967711448669434[s]
# principal_skinner_43.jpg
# []
# Elapsed time = 3.169487237930298[s]
# principal_skinner_44.jpg
# []
# Elapsed time = 3.2325093746185303[s]
# principal_skinner_45.jpg
# []
# Elapsed time = 3.2806639671325684[s]
# principal_skinner_46.jpg
# []
# Elapsed time = 3.3465185165405273[s]
# principal_skinner_47.jpg
# []
# Elapsed time = 3.61958646774292[s]
# principal_skinner_48.jpg
# []
# Elapsed time = 3.293699026107788[s]
# principal_skinner_49.jpg
# []
# Elapsed time = 3.138532876968384[s]
# principal_skinner_5.jpg
# []
# Elapsed time = 3.118894100189209[s]
# principal_skinner_6.jpg
# []
# Elapsed time = 3.141848087310791[s]
# principal_skinner_7.jpg
# []
# Elapsed time = 3.146872043609619[s]
# principal_skinner_8.jpg
# []
# Elapsed time = 3.145904064178467[s]
# principal_skinner_9.jpg
# []
# Elapsed time = 3.1667027473449707[s]
# sideshow_bob_0.jpg
# []
# Elapsed time = 3.1210412979125977[s]
# sideshow_bob_1.jpg
# []
# Elapsed time = 3.1285624504089355[s]
# sideshow_bob_10.jpg
# []
# Elapsed time = 3.1330742835998535[s]
# sideshow_bob_11.jpg
# []
# Elapsed time = 3.118873357772827[s]
# sideshow_bob_12.jpg
# []
# Elapsed time = 3.1382393836975098[s]
# sideshow_bob_13.jpg
# []
# Elapsed time = 3.1252784729003906[s]
# sideshow_bob_14.jpg
# []
# Elapsed time = 3.087306261062622[s]
# sideshow_bob_15.jpg
# []
# Elapsed time = 3.1263628005981445[s]
# sideshow_bob_16.jpg
# []
# Elapsed time = 3.1277523040771484[s]
# sideshow_bob_17.jpg
# []
# Elapsed time = 3.17033314704895[s]
# sideshow_bob_18.jpg
# []
# Elapsed time = 3.205867290496826[s]
# sideshow_bob_19.jpg
# []
# Elapsed time = 3.1658263206481934[s]
# sideshow_bob_2.jpg
# []
# Elapsed time = 3.255178928375244[s]
# sideshow_bob_20.jpg
# []
# Elapsed time = 3.3032212257385254[s]
# sideshow_bob_21.jpg
# []
# Elapsed time = 3.5105156898498535[s]
# sideshow_bob_22.jpg
# []
# Elapsed time = 3.3041841983795166[s]
# sideshow_bob_23.jpg
# []
# Elapsed time = 3.327580690383911[s]
# sideshow_bob_24.jpg
# []
# Elapsed time = 3.2270874977111816[s]
# sideshow_bob_25.jpg
# []
# Elapsed time = 3.2669332027435303[s]
# sideshow_bob_26.jpg
# []
# Elapsed time = 3.3606979846954346[s]
# sideshow_bob_27.jpg
# []
# Elapsed time = 3.241842746734619[s]
# sideshow_bob_28.jpg
# []
# Elapsed time = 3.25909423828125[s]
# sideshow_bob_29.jpg
# []
# Elapsed time = 3.387702226638794[s]
# sideshow_bob_3.jpg
# []
# Elapsed time = 3.2532804012298584[s]
# sideshow_bob_30.jpg
# []
# Elapsed time = 3.1936933994293213[s]
# sideshow_bob_31.jpg
# []
# Elapsed time = 3.2301552295684814[s]
# sideshow_bob_32.jpg
# []
# Elapsed time = 3.2515504360198975[s]
# sideshow_bob_33.jpg
# []
# Elapsed time = 3.3127105236053467[s]
# sideshow_bob_34.jpg
# []
# Elapsed time = 3.4013705253601074[s]
# sideshow_bob_36.jpg
# []
# Elapsed time = 3.5265471935272217[s]
# sideshow_bob_37.jpg
# []
# Elapsed time = 3.2935848236083984[s]
# sideshow_bob_38.jpg
# []
# Elapsed time = 3.168912172317505[s]
# sideshow_bob_39.jpg
# []
# Elapsed time = 3.1585214138031006[s]
# sideshow_bob_4.jpg
# []
# Elapsed time = 3.2892045974731445[s]
# sideshow_bob_40.jpg
# []
# Elapsed time = 3.1672070026397705[s]
# sideshow_bob_41.jpg
# []
# Elapsed time = 3.206700563430786[s]
# sideshow_bob_42.jpg
# []
# Elapsed time = 3.3132927417755127[s]
# sideshow_bob_43.jpg
# []
# Elapsed time = 3.2630045413970947[s]
# sideshow_bob_44.jpg
# []
# Elapsed time = 3.2291512489318848[s]
# sideshow_bob_45.jpg
# []
# Elapsed time = 3.2281203269958496[s]
# sideshow_bob_47.jpg
# []
# Elapsed time = 3.5228991508483887[s]
# sideshow_bob_48.jpg
# []
# Elapsed time = 3.5059025287628174[s]
# sideshow_bob_49.jpg
# []
# Elapsed time = 3.25862717628479[s]
# sideshow_bob_5.jpg
# []
# Elapsed time = 3.2784175872802734[s]
# sideshow_bob_7.jpg
# []
# Elapsed time = 3.391766309738159[s]
# sideshow_bob_8.jpg
# []
# Elapsed time = 3.4426276683807373[s]
# sideshow_bob_9.jpg
# []
# Elapsed time = 3.5413577556610107[s]
# Using TensorFlow backend.
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2023-05-29 20:18:53.116341: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:63: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:488: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3626: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3454: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3603: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From c:\Users\naran\OneDrive\Documents\Python Scripts\ObjectDetection-master\model\RoiPoolingConv.py:105: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3458: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:1255: calling reduce_prod_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:158: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\optimizers.py:711: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ## Problem 2 Code reading
# Please read the code of the above implementation.

# %% [markdown]
# ##Answer
#
# RPN: It generates candidate regions of interest (ROIs) based on the input image. RPN speeds up the calculation of area proposals, which has been a bottleneck in calculation speed.
#
# RoI pooling layer: A convolution layer is shared between RPN and R-CNN in order to improve the efficiency of calculation cost. Therefore, the RoI pooling layer outputs the proposed areas of various sizes in a fixed size.
#
# IOU: The IOU, which is the overlap between the ground truth and the anchor, is calculated to determine the proposed area.
#
# From the train.py
#
# row 71th: model_rpn, model_classifier, model_all = faster_rcnn.get_model(C, classes_count)
#
# load RPN model_rpn using Get_model from faster_rcnn.py
#
# row 102th: R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, K.image_data_format(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
#
# RPN model training, estimation and sending to Roi pooling
#
# The threshold is set to 0.7 and iou is calculated. The maximum number of proposal area boxes is set to 300.

# %% [markdown]
# ## Problem 3 Estimation by learned weights
# How to perform the estimation using the learned weights is described in the Quick Start section of README.md.
#
# First of all, please follow this procedure to perform detection on some images or videos.
#
# Submit the output results as part of the assignment.

# %%
# !python ./yolo3/convert.py ./yolo3/yolov3.cfg ./yolo3/yolov3.weights model_data/yolo_weights.h5
# Out:
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_11
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_3
# Parsing section convolutional_12
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_13
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_4
# Parsing section convolutional_14
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_15
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_5
# Parsing section convolutional_16
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_17
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_6
# Parsing section convolutional_18
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_19
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_7
# Parsing section convolutional_20
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_21
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_8
# Parsing section convolutional_22
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_23
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_9
# Parsing section convolutional_24
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_25
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_10
# Parsing section convolutional_26
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_27
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_28
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_11
# Parsing section convolutional_29
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_30
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_12
# Parsing section convolutional_31
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_32
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_13
# Parsing section convolutional_33
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_34
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_14
# Parsing section convolutional_35
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_36
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_15
# Parsing section convolutional_37
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_38
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_16
# Parsing section convolutional_39
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_40
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_17
# Parsing section convolutional_41
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_42
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_18
# Parsing section convolutional_43
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_44
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_45
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_19
# Parsing section convolutional_46
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_47
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_20
# Parsing section convolutional_48
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_49
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_21
# Parsing section convolutional_50
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_51
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_22
# Parsing section convolutional_52
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_53
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_54
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_55
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_56
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_57
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_58
# conv2d    linear (1, 1, 1024, 255)
# Parsing section yolo_0
# Parsing section route_0
# Parsing section convolutional_59
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section upsample_0
# Parsing section route_1
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_1/ResizeNearestNeighbor:0' shape=(?, ?, ?, 256) dtype=float32>, <tf.Tensor 'add_19/add:0' shape=(?, ?, ?, 512) dtype=float32>]
# Parsing section convolutional_60
# conv2d bn leaky (1, 1, 768, 256)
# Parsing section convolutional_61
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_62
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_63
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_64
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_65
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_66
# conv2d    linear (1, 1, 512, 255)
# Parsing section yolo_1
# Parsing section route_2
# Parsing section convolutional_67
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section upsample_1
# Parsing section route_3
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_2/ResizeNearestNeighbor:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'add_11/add:0' shape=(?, ?, ?, 256) dtype=float32>]
# Parsing section convolutional_68
# conv2d bn leaky (1, 1, 384, 128)
# Parsing section convolutional_69
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_70
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_71
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_72
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_73
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_74
# conv2d    linear (1, 1, 256, 255)
# Parsing section yolo_2
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 2048        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 6 18432       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 6 0           leaky_re_lu_2[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 6 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 73728       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 6 8192        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 8192        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 1 512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, None, None, 1 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 2 294912      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 2 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 1 512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 2 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 2 0           leaky_re_lu_10[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 32768       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 2 1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           add_4[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 32768       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 2 1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           add_5[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 32768       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 1 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 2 1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 2 0           add_6[0][0]
#                                                                  leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 32768       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 1 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 2 1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 2 0           add_7[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 1 32768       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 1 512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 2 1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 2 0           add_8[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 32768       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 1 512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 2 1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 2 0           add_9[0][0]
#                                                                  leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 1 32768       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 1 512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 2 1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 2 0           add_10[0][0]
#                                                                  leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, None, None, 2 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 5 1179648     zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 5 2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 2 1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 5 2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 5 0           leaky_re_lu_27[0][0]
#                                                                  leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 131072      add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 2 1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 5 2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 5 0           add_12[0][0]
#                                                                  leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 2 131072      add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 2 1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 5 2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 5 0           add_13[0][0]
#                                                                  leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 2 131072      add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 2 1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 5 2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 5 0           add_14[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 2 131072      add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 2 1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 5 2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 5 0           add_15[0][0]
#                                                                  leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 2 131072      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 2 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 5 2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 5 0           add_16[0][0]
#                                                                  leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 2 131072      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 2 1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 5 2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 5 0           add_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 2 131072      add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 2 1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 5 2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 5 0           add_18[0][0]
#                                                                  leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, None, None, 5 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 4718592     zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 4096        conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 5 2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 1 0           leaky_re_lu_44[0][0]
#                                                                  leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 5 524288      add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 5 2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 4096        conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 1 0           add_20[0][0]
#                                                                  leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 5 524288      add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 5 2048        conv2d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 4096        conv2d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 1 0           add_21[0][0]
#                                                                  leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 5 524288      add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 5 2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 1 0           add_22[0][0]
#                                                                  leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 5 524288      add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 5 2048        conv2d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 4096        conv2d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 5 2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 4096        conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_56[0][0]
# ...
# leaky_re_lu_60 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 5 2048        conv2d_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 2 1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 5 2048        conv2d_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 2 1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 512         conv2d_68[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 1 0           leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 3 0           up_sampling2d_2[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 49152       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 2 1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 2 1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 1 512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 5 2048        conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 2 1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 2 261375      leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 2 130815      leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 2 65535       leaky_re_lu_72[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# None
# Using TensorFlow backend.
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2023-05-29 22:52:37.882734: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:63: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:488: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:3626: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:1238: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:158: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:163: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\backend\tensorflow_backend.py:1818: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Traceback (most recent call last):
#   File "./yolo3/convert.py", line 262, in <module>
#     _main(parser.parse_args())
#   File "./yolo3/convert.py", line 245, in _main
#     model.save('{}'.format(output_path))
#   File "c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\engine\topology.py", line 2556, in save
#     save_model(self, filepath, overwrite, include_optimizer)
#   File "c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\keras\models.py", line 102, in save_model
#     with h5py.File(filepath, mode='w') as f:
#   File "c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\h5py\_hl\files.py", line 408, in __init__
#     swmr=swmr)
#   File "c:\Users\naran\anaconda3\envs\myenv\lib\site-packages\h5py\_hl\files.py", line 179, in make_fid
#     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#   File "h5py\_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py\_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py\h5f.pyx", line 108, in h5py.h5f.create
# OSError: Unable to create file (unable to open file: name = 'model_data/yolo_weights.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 302)

# %%
# !python ./yolo3/yolo_video.py --image --input=./yolo3/image/i.jpg

# %% [markdown]
# ## Problem 4 Create a file for learning
# Learn new data (Simpsons dataset). Read the Training section of the README.md and create the necessary files to train the Simpsons dataset.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
annotation_df = pd.read_csv('annotation_rcnn.txt',header=None)
print(annotation_df.head())
# Out:
#                                                    0    1    2    3    4  \
# 0  simpsons_dataset/abraham_grampa_simpson/pic_00...   57   72   52   72
# 1  simpsons_dataset/abraham_grampa_simpson/pic_00...   80   31  337  354
# 2  simpsons_dataset/abraham_grampa_simpson/pic_00...  128   48  285  407
# 3  simpsons_dataset/abraham_grampa_simpson/pic_00...   72  126  158  275
# 4  simpsons_dataset/abraham_grampa_simpson/pic_00...  123   61  294  416
#
#                         5
# 0  abraham_grampa_simpson
# 1  abraham_grampa_simpson
# 2  abraham_grampa_simpson
# 3  abraham_grampa_simpson
# 4  abraham_grampa_simpson

# %%
le = LabelEncoder()
annotation_df.iloc[:,5] = le.fit_transform(annotation_df.iloc[:,5])

# %%
rcnn_path = 'annotation_rcnn.txt'
yolo_path = 'annotation.txt'
n_sample, n_col = annotation_df.shape
with open(rcnn_path) as f:
    lines = f.readlines() 
    for i in range(n_sample):
        line = lines[i]
        split_line = line.split(',') 
        image_path = split_line[0]
        split_line[0] = './' + image_path
        split_line[-1] = str(annotation_df.iloc[i,5]) + '\n'  
        with open(yolo_path, mode='a') as out_f:
            join_line = ','.join(split_line)  
            join_line = join_line.replace('.jpg,','.jpg ')  
            out_f.write(join_line)

# %%
annotation_df = pd.read_csv('annotation.txt',header=None)
print(annotation_df.head())
# Out:
#                                                    0    1    2    3  4
# 0  ./simpsons_dataset/abraham_grampa_simpson/pic_...   72   52   72  0
# 1  ./simpsons_dataset/abraham_grampa_simpson/pic_...   31  337  354  0
# 2  ./simpsons_dataset/abraham_grampa_simpson/pic_...   48  285  407  0
# 3  ./simpsons_dataset/abraham_grampa_simpson/pic_...  126  158  275  0
# 4  ./simpsons_dataset/abraham_grampa_simpson/pic_...   61  294  416  0

# %% [markdown]
# ## Problem 5 Confirmation that learning can be done
# Use the file you created in Problem 4 to learn. If it takes a long time to learn in the execution environment, you can just confirm that you can learn.

# %%
# !python ./yolo3/train.py
